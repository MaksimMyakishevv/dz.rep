# %% [markdown]
# ### NLTK

# %%
## Импорт библиотеки, загрузка моделей и словаря wordnet
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\maksm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\maksm\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\maksm\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Токенизация текста
text = ' The way to get started is to quit talking and begin doing'
tokenized = nltk.word_tokenize(text)
tokenized
# Out:
# ['The',
#  'way',
#  'to',
#  'get',
#  'started',
#  'is',
#  'to',
#  'quit',
#  'talking',
#  'and',
#  'begin',
#  'doing']

# %%
# разбор по частям речи
tagged = nltk.pos_tag(tokenized)
tagged
# Out:
# [('The', 'DT'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('started', 'VBN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('quit', 'VB'),
#  ('talking', 'VBG'),
#  ('and', 'CC'),
#  ('begin', 'VB'),
#  ('doing', 'VBG')]

# %%
tagged[3][1]
# Out:
# 'VB'

# %%
# лемматизация
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
lemmatized = [lemm.lemmatize(word) for word in tokenized]
lemmatized
# Out:
# ['The',
#  'way',
#  'to',
#  'get',
#  'started',
#  'is',
#  'to',
#  'quit',
#  'talking',
#  'and',
#  'begin',
#  'doing']

# %%
# лемматизация с учетом части речи
# меняем теги
def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return nltk.corpus.wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return nltk.corpus.wordnet.VERB
    elif nltk_tag.startswith('N'):
        return nltk.corpus.wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return nltk.corpus.wordnet.ADV
    else:          
        return None

tagged
# Out:
# [('The', 'DT'),
#  ('way', 'NN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('started', 'VBN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('quit', 'VB'),
#  ('talking', 'VBG'),
#  ('and', 'CC'),
#  ('begin', 'VB'),
#  ('doing', 'VBG')]

# %%
# Стемминг English
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer(language='english')
stemmed = [stemmer.stem(word) for word in tokenized]
stemmed
'The way to get started is to quit talking and begin doing'
# Out:
# 'The way to get started is to quit talking and begin doing'

# %%
# Стемминг russian
stemmer = SnowballStemmer(language='russian')
text = 'У Лукоморья дуб зеленый, златая цепь на дубе том'
tokenized = nltk.word_tokenize(text)
stemmed = [stemmer.stem(word) for word in tokenized]
stemmed
# Out:
# ['у', 'лукомор', 'дуб', 'зелен', ',', 'злат', 'цеп', 'на', 'дуб', 'том']

# %% [markdown]
# ### pymorphy
# https://pymorphy2.readthedocs.io/en/stable/

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
morph.parse('стали')[0].tag.POS
# Out:
# 'VERB'

# %%
text = 'Варкалось'
morph.parse(text)
# Out:
# [Parse(word='варкалось', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='варкалось', score=0.5000531180282588, methods_stack=((DictionaryAnalyzer(), 'лось', 123, 0), (UnknownPrefixAnalyzer(score_multiplier=0.5), 'варка'))),
#  Parse(word='варкалось', tag=OpencorporaTag('VERB,impf,intr neut,sing,past,indc'), normal_form='варкаться', score=0.4999468819717412, methods_stack=((FakeDictionary(), 'варкалось', 234, 9), (KnownSuffixAnalyzer(min_word_length=4, score_multiplier=0.5), 'алось')))]

# %%
from nltk.corpus import stopwords
stop = stopwords.words('russian')
stop
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
from pymystem3 import Mystem

m = Mystem()
text = '''Первая послевоенная весна была на Верхнем Дону на редкость дружная и напористая. В конце марта из Приазовья подули теплые ветры, и уже через двое суток начисто оголились пески левобережья Дона, в степи вспухли набитые снегом лога и балки, взломав лед, бешено взыграли степные речки, и дороги стали почти совсем непроездны.

В эту недобрую пору бездорожья мне пришлось ехать в станицу Букановскую. И расстояние небольшое — всего лишь около шестидесяти километров, — но одолеть их оказалось не так-то просто. Мы с товарищем выехали до восхода солнца. Пара сытых лошадей, в струну натягивая постромки, еле тащила тяжелую бричку. Колеса по самую ступицу проваливались в отсыревший, перемешанный со снегом и льдом песок, и через час на лошадиных боках и стегнах, под тонкими ремнями шлеек, уже показались белые пышные хлопья мыла, а в утреннем свежем воздухе остро и пьяняще запахло лошадиным потом и согретым деготьком щедро смазанной конской сбруи.

Там, где было особенно трудно лошадям, мы слезали с брички, шли пешком. Под сапогами хлюпал размокший снег, идти было тяжело, но по обочинам дороги все еще держался хрустально поблескивавший на солнце ледок, и там пробираться было еще труднее. Только часов через шесть покрыли расстояние в тридцать километров, подъехали к переправе через речку Еланку.

Небольшая, местами пересыхающая летом речушка против хутора Моховского в заболоченной, поросшей ольхами пойме разлилась на целый километр. Переправляться надо было на утлой плоскодонке, поднимавшей не больше трех человек. Мы отпустили лошадей. На той стороне в колхозном сарае нас ожидал старенький, видавший виды «виллис», оставленный там еще зимою. Вдвоем с шофером мы не без опасения сели в ветхую лодчонку. Товарищ с вещами остался на берегу. Едва отчалили, как из прогнившего днища в разных местах фонтанчиками забила вода. Подручными средствами конопатили ненадежную посудину и вычерпывали из нее воду, пока не доехали. Через час мы были на той стороне Еланки. Шофер пригнал из хутора машину, подошел к лодке и сказал, берясь за весло:

— Если это проклятое корыто не развалится на воде, — часа через два приедем, раньше не ждите.

Хутор раскинулся далеко в стороне, и возле причала стояла такая тишина, какая бывает в безлюдных местах только глухою осенью и в самом начале весны. От воды тянуло сыростью, терпкой горечью гниющей ольхи, а с дальних прихоперских степей, тонувших в сиреневой дымке тумана, легкий ветерок нес извечно юный, еле уловимый аромат недавно освободившейся из-под снега земли.

Неподалеку, на прибрежном песке, лежал поваленный плетень. Я присел на него, хотел закурить, но сунув руку в правый карман ватной стеганки, к великому огорчению, обнаружил, что пачка «Беломора» совершенно размокла. Во время переправы волна хлестнула через борт низко сидевшей лодки, по пояс окатила меня мутной водой. Тогда мне некогда было думать о папиросах, надо было, бросив весло, побыстрее вычерпывать воду, чтобы лодка не затонула, а теперь, горько досадуя на свою оплошность, я бережно извлек из кармана раскисшую пачку, присел на корточки и стал по одной раскладывать на плетне влажные, побуревшие папиросы.

Был полдень. Солнце светило горячо, как в мае. Я надеялся, что папиросы скоро высохнут. Солнце светило так горячо, что я уже пожалел о том, что надел в дорогу солдатские ватные штаны и стеганку. Это был первый после зимы по-настоящему теплый день. Хорошо было сидеть на плетне вот так, одному, целиком покорясь тишине и одиночеству, и, сняв с головы старую солдатскую ушанку, сушить на ветерке мокрые после тяжелой гребли волосы, бездумно следить за проплывающими в блеклой синеве белыми грудастыми облаками.

Вскоре я увидел, как из-за крайних дворов хутора вышел на дорогу мужчина. Он вел за руку маленького мальчика, судя по росту — лет пяти-шести, не больше. Они устало брели по направлению к переправе, но, поравнявшись с машиной, повернули ко мне. Высокий, сутуловатый мужчина, подойдя вплотную, сказал приглушенным баском:'''
words = text.split()
filtered_words = [word for word in words if word.lower() not in stop]
filtered_text = " ".join(filtered_words)
tokenized = nltk.word_tokenize(filtered_text)
tokenized
m.analyze(filtered_text)
# Out:
# [{'analysis': [{'lex': 'первый', 'wt': 1, 'gr': 'ANUM=им,ед,жен'}],
#   'text': 'Первая'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'послевоенный', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'послевоенная'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'весна', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'весна'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'верхний',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}],
#   'text': 'Верхнем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дон',
#     'wt': 0.9536434637,
#     'gr': 'S,гео,ед,муж,неод=(дат|местн)'}],
#   'text': 'Дону'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'редкость',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,ед|им,ед)'}],
#   'text': 'редкость'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дружный', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'дружная'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'напористый', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'напористая'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'конец', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'конце'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'март', 'wt': 0.6351760138, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'марта'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приазовье',
#     'wt': 0.8416504189,
#     'qual': 'bastard',
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'Приазовья'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'подуть', 'wt': 1, 'gr': 'V,сов,нп=прош,мн,изъяв'}],
#   'text': 'подули'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'теплый',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'теплые'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ветер', 'wt': 1, 'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'ветры'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'двое', 'wt': 1, 'gr': 'NUM=(им|вин,неод)'}],
#   'text': 'двое'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сутки', 'wt': 1, 'gr': 'S,мн,неод=род'}],
#   'text': 'суток'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'начисто', 'wt': 1, 'gr': 'ADV='}], 'text': 'начисто'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'оголяться', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'оголились'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'песок',
#     'wt': 0.982175695,
#     'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'пески'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'левобережье',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'левобережья'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дон',
#     'wt': 0.8678820993,
#     'gr': 'S,гео,ед,муж,неод=род'}],
#   'text': 'Дона'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'степь',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}],
#   'text': 'степи'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вспухать', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'вспухли'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'набивать',
#     'wt': 0.6244198108,
#     'gr': 'V,пе=(прош,вин,мн,прич,полн,сов,страд,неод|прош,им,мн,прич,полн,сов,страд)'}],
#   'text': 'набитые'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'снег', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'снегом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лог',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'лога'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'балка',
#     'wt': 0.9878146049,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'балки'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'взламывать', 'wt': 1, 'gr': 'V,пе=прош,деепр,сов'}],
#   'text': 'взломав'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лед',
#     'wt': 0.9999652444,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'лед'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'бешено', 'wt': 0.9328825914, 'gr': 'ADV='}],
#   'text': 'бешено'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взыграть', 'wt': 1, 'gr': 'V,сов,нп=прош,мн,изъяв'}],
#   'text': 'взыграли'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'степной',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'степные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'речка',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'речки'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'дорога',
#     'wt': 0.9530183047,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'дороги'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'становиться',
#     'wt': 0.9821285244,
#     'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'стали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'непроездна',
#     'wt': 0.9082833788,
#     'qual': 'bastard',
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'непроездны'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'недобрый', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'недобрую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пора', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'пору'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'бездорожье',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'бездорожья'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приходиться',
#     'wt': 0.9982644245,
#     'gr': 'V,нп=прош,ед,изъяв,сред,сов'}],
#   'text': 'пришлось'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ехать', 'wt': 1, 'gr': 'V,несов,нп=инф'}],
#   'text': 'ехать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'станица', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'станицу'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'букановский',
#     'wt': 0.8822770926,
#     'qual': 'bastard',
#     'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'Букановскую'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'расстояние',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'расстояние'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'небольшой',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}],
#   'text': 'небольшое'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'лишь', 'wt': 0.9548535059, 'gr': 'PART='}],
#   'text': 'лишь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'около', 'wt': 0.9781960145, 'gr': 'PR='}],
#   'text': 'около'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'шестьдесят', 'wt': 1, 'gr': 'NUM=(пр|дат|род)'}],
#   'text': 'шестидесяти'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'километр',
#     'wt': 0.9980160698,
#     'gr': 'S,муж,неод=род,мн'}],
#   'text': 'километров'},
#  {'text': ', — '},
#  {'analysis': [{'lex': 'одолевать', 'wt': 1, 'gr': 'V,пе=инф,сов'}],
#   'text': 'одолеть'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'оказываться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,сред,сов'}],
#   'text': 'оказалось'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'так-то', 'wt': 0.9497490971, 'gr': 'PART='}],
#   'text': 'так-то'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'просто', 'wt': 0.1797087043, 'gr': 'ADV='}],
#   'text': 'просто'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'товарищ', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}],
#   'text': 'товарищем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'выезжать',
#     'wt': 0.9926096021,
#     'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'выехали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'восход', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'восхода'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'солнце',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'солнца'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'пара', 'wt': 0.8380485508, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'Пара'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сытый',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'сытых'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лошадь', 'wt': 1, 'gr': 'S,жен,од=(вин,мн|род,мн)'}],
#   'text': 'лошадей'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'струна', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'струну'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'натягивать',
#     'wt': 1,
#     'gr': 'V,пе=непрош,деепр,несов'}],
#   'text': 'натягивая'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'постромка',
#     'wt': 0.7973993134,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'постромки'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'еле', 'wt': 0.9901185567, 'gr': 'ADV='}],
#   'text': 'еле'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тащить',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,жен'}],
#   'text': 'тащила'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тяжелый', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'тяжелую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'бричка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'бричку'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'колесо',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'Колеса'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'самый', 'wt': 1, 'gr': 'APRO=вин,ед,жен'}],
#   'text': 'самую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ступица', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'ступицу'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'проваливаться',
#     'wt': 1,
#     'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'проваливались'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отсыревать',
#     'wt': 1,
#     'gr': 'V,нп=(прош,вин,ед,прич,полн,муж,сов,действ,неод|прош,им,ед,прич,полн,муж,сов,действ)'}],
#   'text': 'отсыревший'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'перемешать',
#     'wt': 1,
#     'gr': 'V,сов,пе=(прош,вин,ед,прич,полн,муж,страд,неод|прош,им,ед,прич,полн,муж,страд)'}],
#   'text': 'перемешанный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'снег', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'снегом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лед', 'wt': 1, 'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'льдом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'песок', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'песок'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'час', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'час'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лошадиный',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'лошадиных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'бок', 'wt': 1, 'gr': 'S,муж,неод=пр,мн'}],
#   'text': 'боках'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'стегно', 'wt': 1, 'gr': 'S,сред,неод=пр,мн'}],
#   'text': 'стегнах'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'тонкий', 'wt': 1, 'gr': 'A=твор,мн,полн'}],
#   'text': 'тонкими'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ремень', 'wt': 1, 'gr': 'S,муж,неод=твор,мн'}],
#   'text': 'ремнями'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'шлейка', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}],
#   'text': 'шлеек'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'показываться',
#     'wt': 1,
#     'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'показались'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'белый',
#     'wt': 0.9948287685,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'белые'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пышный',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'пышные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хлопья', 'wt': 1, 'gr': 'S,мн,неод=(вин|им)'}],
#   'text': 'хлопья'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мыло',
#     'wt': 0.558479001,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'мыла'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'утренний',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}],
#   'text': 'утреннем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'свежий',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}],
#   'text': 'свежем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'воздух', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'воздухе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'остро', 'wt': 0.9799582738, 'gr': 'ADV='}],
#   'text': 'остро'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пьянящий', 'wt': 1, 'gr': 'A=ед,кр,сред'}],
#   'text': 'пьяняще'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'запахнуть',
#     'wt': 1,
#     'gr': 'V,сов,нп=прош,ед,изъяв,сред'}],
#   'text': 'запахло'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лошадиный',
#     'wt': 1,
#     'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#   'text': 'лошадиным'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'согревать',
#     'wt': 1,
#     'gr': 'V,пе=(прош,дат,мн,прич,полн,сов,страд|прош,твор,ед,прич,полн,муж,сов,страд|прош,твор,ед,прич,полн,сред,сов,страд)'}],
#   'text': 'согретым'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'деготько',
#     'wt': 0,
#     'qual': 'bastard',
#     'gr': 'S,имя,ед,муж,од=твор'}],
#   'text': 'деготьком'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'щедро', 'wt': 0.9813439819, 'gr': 'ADV='}],
#   'text': 'щедро'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'смазывать',
#     'wt': 1,
#     'gr': 'V=(прош,пр,ед,прич,полн,жен,сов,страд|прош,дат,ед,прич,полн,жен,сов,страд|прош,род,ед,прич,полн,жен,сов,страд|прош,твор,ед,прич,полн,жен,сов,страд)'}],
#   'text': 'смазанной'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'конский',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'конской'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сбруя',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'сбруи'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'там', 'wt': 0.9102368948, 'gr': 'ADVPRO='}],
#   'text': 'Там'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'особенно', 'wt': 0.9996672244, 'gr': 'ADV='}],
#   'text': 'особенно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'трудно', 'wt': 0.1313382518, 'gr': 'ADV='}],
#   'text': 'трудно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лошадь', 'wt': 1, 'gr': 'S,жен,од=дат,мн'}],
#   'text': 'лошадям'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'слезать', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,несов'}],
#   'text': 'слезали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'бричка',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'брички'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'идти',
#     'wt': 0.9984090711,
#     'gr': 'V,несов,нп=прош,мн,изъяв'}],
#   'text': 'шли'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пешком', 'wt': 1, 'gr': 'ADV='}], 'text': 'пешком'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сапог', 'wt': 1, 'gr': 'S,муж,неод=твор,мн'}],
#   'text': 'сапогами'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хлюпать',
#     'wt': 1,
#     'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'хлюпал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'размокать',
#     'wt': 1,
#     'gr': 'V,нп=(прош,вин,ед,прич,полн,муж,сов,действ,неод|прош,им,ед,прич,полн,муж,сов,действ)'}],
#   'text': 'размокший'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'снег', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'снег'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'идти', 'wt': 1, 'gr': 'V,несов,нп=инф'}],
#   'text': 'идти'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тяжело', 'wt': 0.6656756475, 'gr': 'ADV='}],
#   'text': 'тяжело'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'обочина', 'wt': 1, 'gr': 'S,жен,неод=дат,мн'}],
#   'text': 'обочинам'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дорога',
#     'wt': 0.9530183047,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'дороги'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'держаться',
#     'wt': 1,
#     'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'держался'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хрустальный', 'wt': 1, 'gr': 'A=ед,кр,сред'}],
#   'text': 'хрустально'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'поблескивать',
#     'wt': 1,
#     'gr': 'V,несов,нп=(прош,вин,ед,прич,полн,муж,действ,неод|прош,им,ед,прич,полн,муж,действ)'}],
#   'text': 'поблескивавший'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'солнце',
#     'wt': 1,
#     'gr': 'S,сред,неод=(пр,ед|вин,ед|им,ед)'}],
#   'text': 'солнце'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ледок',
#     'wt': 0.9992748011,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'ледок'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'пробираться', 'wt': 1, 'gr': 'V,нп=инф,несов'}],
#   'text': 'пробираться'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'трудно', 'wt': 0.3992974037, 'gr': 'ADV=срав'}],
#   'text': 'труднее'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'час', 'wt': 0.7444524321, 'gr': 'S,муж,неод=род,мн'}],
#   'text': 'часов'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'шесть', 'wt': 1, 'gr': 'NUM=(вин|им)'}],
#   'text': 'шесть'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'покрывать', 'wt': 1, 'gr': 'V=прош,мн,изъяв,сов'}],
#   'text': 'покрыли'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'расстояние',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'расстояние'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тридцать', 'wt': 1, 'gr': 'NUM=(вин|им)'}],
#   'text': 'тридцать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'километр',
#     'wt': 0.9980160698,
#     'gr': 'S,муж,неод=род,мн'}],
#   'text': 'километров'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'подъезжать', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'подъехали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'переправа',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'переправе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'речка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'речку'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'еланка',
#     'wt': 0.02054654092,
#     'qual': 'bastard',
#     'gr': 'S,жен,од=вин,ед'}],
#   'text': 'Еланку'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'небольшой', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'Небольшая'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'место',
#     'wt': 0.9895838415,
#     'gr': 'S,сред,неод=твор,мн'}],
#   'text': 'местами'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пересыхать',
#     'wt': 1,
#     'gr': 'V,нп=непрош,им,ед,прич,полн,жен,несов,действ'}],
#   'text': 'пересыхающая'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лето',
#     'wt': 0.9499403607,
#     'gr': 'S,ед,сред,неод=твор'}],
#   'text': 'летом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'речушка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'речушка'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'против', 'wt': 0.9418668814, 'gr': 'PR='}],
#   'text': 'против'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хутор',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'хутора'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'моховский',
#     'wt': 1,
#     'qual': 'bastard',
#     'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}],
#   'text': 'Моховского'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'заболоченный',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'заболоченной'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'порастать',
#     'wt': 1,
#     'gr': 'V,нп=(прош,пр,ед,прич,полн,жен,сов,действ|прош,дат,ед,прич,полн,жен,сов,действ|прош,род,ед,прич,полн,жен,сов,действ|прош,твор,ед,прич,полн,жен,сов,действ)'}],
#   'text': 'поросшей'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ольха', 'wt': 1, 'gr': 'S,жен,неод=твор,мн'}],
#   'text': 'ольхами'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пойма', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'пойме'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'разливаться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,жен,сов'}],
#   'text': 'разлилась'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'целый',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'целый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'километр',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'километр'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'переправляться', 'wt': 1, 'gr': 'V,нп=инф,несов'}],
#   'text': 'Переправляться'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'утлый',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'утлой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'плоскодонка',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'плоскодонке'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'подымать',
#     'wt': 1,
#     'gr': 'V=(прош,пр,ед,прич,полн,жен,несов,действ,пе|прош,дат,ед,прич,полн,жен,несов,действ,пе|прош,род,ед,прич,полн,жен,несов,действ,пе|прош,твор,ед,прич,полн,жен,несов,действ,пе)'}],
#   'text': 'поднимавшей'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'три', 'wt': 1, 'gr': 'NUM=(пр|род|вин,од)'}],
#   'text': 'трех'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'человек',
#     'wt': 1,
#     'gr': 'S,муж,од=(вин,мн|род,мн|им,ед)'}],
#   'text': 'человек'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отпускать', 'wt': 1, 'gr': 'V=прош,мн,изъяв,сов'}],
#   'text': 'отпустили'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лошадь', 'wt': 1, 'gr': 'S,жен,од=(вин,мн|род,мн)'}],
#   'text': 'лошадей'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тот',
#     'wt': 0.9998024292,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}],
#   'text': 'той'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сторона', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'стороне'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'колхозный',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}],
#   'text': 'колхозном'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сарай', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'сарае'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ожидать',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'ожидал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'старенький',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'старенький'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'видать',
#     'wt': 1,
#     'gr': 'V,несов,пе=(прош,вин,ед,прич,полн,муж,действ,неод|прош,им,ед,прич,полн,муж,действ)'}],
#   'text': 'видавший'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вид',
#     'wt': 0.9999857995,
#     'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'виды'},
#  {'text': ' «'},
#  {'analysis': [{'lex': 'виллис', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'виллис'},
#  {'text': '», '},
#  {'analysis': [{'lex': 'оставлять',
#     'wt': 1,
#     'gr': 'V,пе=(прош,вин,ед,прич,полн,муж,сов,страд,неод|прош,им,ед,прич,полн,муж,сов,страд)'}],
#   'text': 'оставленный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'зима',
#     'wt': 0.7498531373,
#     'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'зимою'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'вдвоем', 'wt': 1, 'gr': 'ADV='}], 'text': 'Вдвоем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'шофер', 'wt': 1, 'gr': 'S,муж,од=твор,ед'}],
#   'text': 'шофером'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'опасение',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'опасения'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'садиться',
#     'wt': 0.9988081976,
#     'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'сели'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ветхий', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'ветхую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лодчонка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'лодчонку'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'товарищ', 'wt': 1, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Товарищ'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вещь', 'wt': 1, 'gr': 'S,жен,неод=твор,мн'}],
#   'text': 'вещами'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'оставаться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'остался'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'берег',
#     'wt': 0.9689970754,
#     'gr': 'S,муж,неод=(дат,ед|местн,ед)'}],
#   'text': 'берегу'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'едва', 'wt': 0.7822803131, 'gr': 'ADV='}],
#   'text': 'Едва'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отчаливать', 'wt': 1, 'gr': 'V,пе=прош,мн,изъяв,сов'}],
#   'text': 'отчалили'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'прогнивать',
#     'wt': 1,
#     'gr': 'V,нп=(прош,вин,ед,прич,полн,муж,сов,действ,од|прош,род,ед,прич,полн,муж,сов,действ|прош,род,ед,прич,полн,сред,сов,действ)'}],
#   'text': 'прогнившего'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'днище',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'днища'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'разный',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'разных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'место', 'wt': 1, 'gr': 'S,сред,неод=пр,мн'}],
#   'text': 'местах'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'фонтанчик', 'wt': 1, 'gr': 'S,муж,неод=твор,мн'}],
#   'text': 'фонтанчиками'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'забивать',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,жен,сов'}],
#   'text': 'забила'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вода', 'wt': 0.9999788483, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'вода'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'подручный',
#     'wt': 0.1526729946,
#     'gr': 'A=твор,мн,полн'}],
#   'text': 'Подручными'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'средство',
#     'wt': 0.9957443634,
#     'gr': 'S,сред,неод=твор,мн'}],
#   'text': 'средствами'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'конопатить',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,мн,изъяв'}],
#   'text': 'конопатили'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ненадежный', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'ненадежную'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'посудина', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'посудину'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вычерпывать',
#     'wt': 1,
#     'gr': 'V,пе=прош,мн,изъяв,несов'}],
#   'text': 'вычерпывали'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вода', 'wt': 0.9999290493, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'воду'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'пока', 'wt': 0.6671385998, 'gr': 'CONJ='}],
#   'text': 'пока'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'доезжать', 'wt': 1, 'gr': 'V,нп=прош,мн,изъяв,сов'}],
#   'text': 'доехали'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'час', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'час'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тот',
#     'wt': 0.9998024292,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}],
#   'text': 'той'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сторона', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'стороне'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'еланка',
#     'wt': 0.03903255886,
#     'qual': 'bastard',
#     'gr': 'S,жен,од=(род,ед|им,мн)'}],
#   'text': 'Еланки'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'шофер', 'wt': 1, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'Шофер'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пригонять', 'wt': 1, 'gr': 'V=прош,ед,изъяв,муж,сов'}],
#   'text': 'пригнал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хутор',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'хутора'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'машина',
#     'wt': 0.9998631677,
#     'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'машину'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'подходить',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'подошел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лодка', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'лодке'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сказать',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'сказал'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'браться', 'wt': 1, 'gr': 'V,несов,нп=непрош,деепр'}],
#   'text': 'берясь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'весло', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'весло'},
#  {'text': ': — '},
#  {'analysis': [{'lex': 'это',
#     'wt': 0.7809833731,
#     'gr': 'SPRO,ед,сред,неод=(вин|им)'}],
#   'text': 'это'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'проклятый',
#     'wt': 0.9374149986,
#     'gr': 'A=(вин,ед,полн,сред|им,ед,полн,сред)'}],
#   'text': 'проклятое'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'корыто', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'корыто'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'разваливаться',
#     'wt': 1,
#     'gr': 'V,нп=непрош,ед,изъяв,3-л,сов'}],
#   'text': 'развалится'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вода',
#     'wt': 0.9999487595,
#     'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'воде'},
#  {'text': ', — '},
#  {'analysis': [{'lex': 'час', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'часа'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приезжать',
#     'wt': 1,
#     'gr': 'V,нп=(мн,пов,1-л,сов|непрош,мн,изъяв,1-л,сов)'}],
#   'text': 'приедем'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'рано', 'wt': 0.998527234, 'gr': 'ADV=срав'}],
#   'text': 'раньше'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ждать', 'wt': 1, 'gr': 'V,несов,пе=мн,пов,2-л'}],
#   'text': 'ждите'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'хутор', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'Хутор'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'раскидываться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'раскинулся'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'далеко', 'wt': 0.9860391288, 'gr': 'ADV='}],
#   'text': 'далеко'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сторона', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'стороне'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'возле', 'wt': 0.9863990327, 'gr': 'PR='}],
#   'text': 'возле'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'причал', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'причала'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'стоять',
#     'wt': 0.9999682913,
#     'gr': 'V,несов,нп=прош,ед,изъяв,жен'}],
#   'text': 'стояла'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'такой', 'wt': 0.9989608709, 'gr': 'APRO=им,ед,жен'}],
#   'text': 'такая'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тишина',
#     'wt': 0.9971559716,
#     'gr': 'S,ед,жен,неод=им'}],
#   'text': 'тишина'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'бывать',
#     'wt': 1,
#     'gr': 'V,несов,нп=непрош,ед,изъяв,3-л'}],
#   'text': 'бывает'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'безлюдный',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'безлюдных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'место', 'wt': 1, 'gr': 'S,сред,неод=пр,мн'}],
#   'text': 'местах'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'глухой',
#     'wt': 0.966709034,
#     'gr': 'A=твор,ед,полн,жен'}],
#   'text': 'глухою'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'осень',
#     'wt': 0.9667493593,
#     'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'осенью'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'самый',
#     'wt': 0.7869908294,
#     'gr': 'APRO=(пр,ед,муж|пр,ед,сред)'}],
#   'text': 'самом'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'начало', 'wt': 1, 'gr': 'S,сред,неод=пр,ед'}],
#   'text': 'начале'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'весна',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'весны'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вода',
#     'wt': 0.9995265239,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'воды'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тянуть',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,сред'}],
#   'text': 'тянуло'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сырость', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'сыростью'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'терпкий',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'терпкой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'горечь', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'горечью'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'гнить',
#     'wt': 1,
#     'gr': 'V,несов,нп=(непрош,пр,ед,прич,полн,жен,действ|непрош,дат,ед,прич,полн,жен,действ|непрош,род,ед,прич,полн,жен,действ|непрош,твор,ед,прич,полн,жен,действ)'}],
#   'text': 'гниющей'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ольха',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'ольхи'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'дальний',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'дальних'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'прихоперский',
#     'wt': 1,
#     'qual': 'bastard',
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'прихоперских'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'степь', 'wt': 1, 'gr': 'S,жен,неод=род,мн'}],
#   'text': 'степей'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'тонуть',
#     'wt': 1,
#     'gr': 'V,несов,нп=(прош,пр,мн,прич,полн,действ|прош,род,мн,прич,полн,действ|прош,вин,мн,прич,полн,действ,од)'}],
#   'text': 'тонувших'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сиреневый',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'сиреневой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дымка',
#     'wt': 0.1897002854,
#     'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'дымке'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'туман', 'wt': 1, 'gr': 'S,муж,неод=род,ед'}],
#   'text': 'тумана'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'легкий',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'легкий'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ветерок', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'ветерок'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'нести',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'нес'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'извечно', 'wt': 0.6362835973, 'gr': 'ADV='}],
#   'text': 'извечно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'юный',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'юный'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'еле', 'wt': 0.9901185567, 'gr': 'ADV='}],
#   'text': 'еле'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'уловимый',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'уловимый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'аромат', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'аромат'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'недавно', 'wt': 1, 'gr': 'ADV='}], 'text': 'недавно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'освобождаться',
#     'wt': 1,
#     'gr': 'V,нп=(прош,пр,ед,прич,полн,жен,сов,действ|прош,дат,ед,прич,полн,жен,сов,действ|прош,род,ед,прич,полн,жен,сов,действ|прош,твор,ед,прич,полн,жен,сов,действ)'}],
#   'text': 'освободившейся'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'из-под', 'wt': 1, 'gr': 'PR='}], 'text': 'из-под'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'снег',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'снега'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'земля',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'земли'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'неподалеку', 'wt': 1, 'gr': 'ADV='}],
#   'text': 'Неподалеку'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'прибрежный',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,муж|пр,ед,полн,сред)'}],
#   'text': 'прибрежном'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'песок', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'песке'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'лежать',
#     'wt': 0.999830923,
#     'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'лежал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'повалить',
#     'wt': 0.5488301663,
#     'gr': 'V,сов,пе=(прош,вин,ед,прич,полн,муж,страд,неод|прош,им,ед,прич,полн,муж,страд)'}],
#   'text': 'поваленный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'плетень', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'плетень'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приседать',
#     'wt': 0.9297345919,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'присел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'он',
#     'wt': 0.951862938,
#     'gr': 'SPRO,ед,3-л,муж=(вин|род)'}],
#   'text': 'него'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'хотеть',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'хотел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'закуривать', 'wt': 1, 'gr': 'V,пе=инф,сов'}],
#   'text': 'закурить'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'сунуть', 'wt': 1, 'gr': 'V,сов,пе=прош,деепр'}],
#   'text': 'сунув'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'рука', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'руку'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'правый',
#     'wt': 0.922760994,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'правый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'карман',
#     'wt': 0.9999975941,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'карман'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ватный',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'ватной'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'стеганка',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'стеганки'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'великий',
#     'wt': 1,
#     'gr': 'A=(дат,ед,полн,муж|дат,ед,полн,сред)'}],
#   'text': 'великому'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'огорчение', 'wt': 1, 'gr': 'S,сред,неод=дат,ед'}],
#   'text': 'огорчению'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'обнаруживать',
#     'wt': 1,
#     'gr': 'V,пе=прош,ед,изъяв,муж,сов'}],
#   'text': 'обнаружил'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'пачка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'пачка'},
#  {'text': ' «'},
#  {'analysis': [{'lex': 'беломор',
#     'wt': 0.9311426717,
#     'gr': 'S,муж,неод=род,ед'}],
#   'text': 'Беломора'},
#  {'text': '» '},
#  {'analysis': [{'lex': 'совершенно', 'wt': 0.9930218951, 'gr': 'ADV='}],
#   'text': 'совершенно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'размокать',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,жен,сов'}],
#   'text': 'размокла'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'время', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'время'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'переправа',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'переправы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'волна', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'волна'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хлестнуть',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,жен'}],
#   'text': 'хлестнула'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'борт', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'борт'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'низко', 'wt': 0.9600869867, 'gr': 'ADV='}],
#   'text': 'низко'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сидеть',
#     'wt': 1,
#     'gr': 'V,несов,нп=(прош,пр,ед,прич,полн,жен,действ|прош,дат,ед,прич,полн,жен,действ|прош,род,ед,прич,полн,жен,действ|прош,твор,ед,прич,полн,жен,действ)'}],
#   'text': 'сидевшей'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'лодка',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'лодки'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'пояс', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'пояс'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'окачивать',
#     'wt': 1,
#     'gr': 'V=прош,ед,изъяв,жен,сов,пе'}],
#   'text': 'окатила'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мутный',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'мутной'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вода', 'wt': 1, 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'водой'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'некогда', 'wt': 0.3927576298, 'gr': 'ADV,прдк='}],
#   'text': 'некогда'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'думать', 'wt': 0.9777744627, 'gr': 'V,несов,нп=инф'}],
#   'text': 'думать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'папироса', 'wt': 1, 'gr': 'S,жен,неод=пр,мн'}],
#   'text': 'папиросах'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'быть',
#     'wt': 0.975680698,
#     'gr': 'V,нп=прош,ед,изъяв,сред,несов'}],
#   'text': 'было'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'бросать', 'wt': 1, 'gr': 'V=прош,деепр,сов,пе'}],
#   'text': 'бросив'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'весло', 'wt': 1, 'gr': 'S,сред,неод=(вин,ед|им,ед)'}],
#   'text': 'весло'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'быстро', 'wt': 0, 'gr': 'ADV=срав'}],
#   'text': 'побыстрее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вычерпывать', 'wt': 1, 'gr': 'V,пе=инф,несов'}],
#   'text': 'вычерпывать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вода', 'wt': 0.9999290493, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'воду'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'лодка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'лодка'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'затонуть',
#     'wt': 1,
#     'gr': 'V,сов,нп=прош,ед,изъяв,жен'}],
#   'text': 'затонула'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'теперь', 'wt': 1, 'gr': 'ADV='}], 'text': 'теперь'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'горько', 'wt': 0.6056800085, 'gr': 'ADV='}],
#   'text': 'горько'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'досадовать',
#     'wt': 1,
#     'gr': 'V,несов,нп=непрош,деепр'}],
#   'text': 'досадуя'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'оплошность',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,ед|им,ед)'}],
#   'text': 'оплошность'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'бережно', 'wt': 0.9920530215, 'gr': 'ADV='}],
#   'text': 'бережно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'извлекать', 'wt': 1, 'gr': 'V=прош,ед,изъяв,муж,сов'}],
#   'text': 'извлек'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'карман',
#     'wt': 0.9988878707,
#     'gr': 'S,муж,неод=род,ед'}],
#   'text': 'кармана'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'раскисший',
#     'wt': 0.1760348837,
#     'gr': 'A,полн=вин,ед,жен'}],
#   'text': 'раскисшую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пачка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'пачку'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'приседать',
#     'wt': 0.9297345919,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'присел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'корточки', 'wt': 1, 'gr': 'S,мн,неод=(вин|им)'}],
#   'text': 'корточки'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'становиться',
#     'wt': 1,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'стал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'один',
#     'wt': 0.7485076346,
#     'gr': 'APRO=(пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен)'}],
#   'text': 'одной'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'раскладывать', 'wt': 1, 'gr': 'V,пе=инф,несов'}],
#   'text': 'раскладывать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'плетень', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'плетне'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'влажный',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'влажные'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'побуреть',
#     'wt': 1,
#     'gr': 'V,сов,нп=(прош,им,мн,прич,полн,действ|прош,вин,мн,прич,полн,действ,неод)'}],
#   'text': 'побуревшие'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'папироса',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'папиросы'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'полдень', 'wt': 1, 'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'полдень'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'солнце',
#     'wt': 1,
#     'gr': 'S,сред,неод=(пр,ед|вин,ед|им,ед)'}],
#   'text': 'Солнце'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'светить',
#     'wt': 0.3915217195,
#     'gr': 'V,несов,нп=прош,ед,изъяв,сред'}],
#   'text': 'светило'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'горячо', 'wt': 0.9726838965, 'gr': 'ADV='}],
#   'text': 'горячо'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'май', 'wt': 0.9811308276, 'gr': 'S,ед,муж,неод=пр'}],
#   'text': 'мае'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'надеяться',
#     'wt': 1,
#     'gr': 'V,несов,нп=прош,ед,изъяв,муж'}],
#   'text': 'надеялся'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'папироса',
#     'wt': 1,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'папиросы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'скоро', 'wt': 0.9982715536, 'gr': 'ADV='}],
#   'text': 'скоро'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'высыхать',
#     'wt': 1,
#     'gr': 'V,нп=непрош,мн,изъяв,3-л,сов'}],
#   'text': 'высохнут'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'солнце',
#     'wt': 1,
#     'gr': 'S,сред,неод=(пр,ед|вин,ед|им,ед)'}],
#   'text': 'Солнце'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'светить',
#     'wt': 0.3915217195,
#     'gr': 'V,несов,нп=прош,ед,изъяв,сред'}],
#   'text': 'светило'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'горячо', 'wt': 0.9726838965, 'gr': 'ADV='}],
#   'text': 'горячо'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'пожалеть',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'пожалел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'то',
#     'wt': 0.7345964956,
#     'gr': 'SPRO,ед,сред,неод=пр'}],
#   'text': 'том'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'надевать',
#     'wt': 0.9704238054,
#     'gr': 'V,пе=прош,ед,изъяв,муж,сов'}],
#   'text': 'надел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дорога', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'дорогу'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'солдатский',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'солдатские'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ватный',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'ватные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'штаны', 'wt': 1, 'gr': 'S,мн,неод=(вин|им)'}],
#   'text': 'штаны'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'стеганка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'стеганку'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'это', 'wt': 0.1633604427, 'gr': 'PART='}],
#   'text': 'Это'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'первый',
#     'wt': 1,
#     'gr': 'ANUM=(вин,ед,муж,неод|им,ед,муж)'}],
#   'text': 'первый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'зима',
#     'wt': 0.9994518522,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'зимы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'по-настоящему', 'wt': 1, 'gr': 'ADV='}],
#   'text': 'по-настоящему'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'теплый',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'теплый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'день',
#     'wt': 0.999920149,
#     'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#   'text': 'день'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сидеть', 'wt': 1, 'gr': 'V,несов,нп=инф'}],
#   'text': 'сидеть'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'плетень', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'плетне'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'так', 'wt': 0.9840554802, 'gr': 'ADVPRO='}],
#   'text': 'так'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'один',
#     'wt': 0.2427401682,
#     'gr': 'ANUM=(дат,ед,муж|дат,ед,сред)'}],
#   'text': 'одному'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'целиком', 'wt': 0.9998118282, 'gr': 'ADV='}],
#   'text': 'целиком'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'покориться',
#     'wt': 0.4649202935,
#     'qual': 'bastard',
#     'gr': 'V,несов,нп=непрош,деепр'}],
#   'text': 'покорясь'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тишина',
#     'wt': 0.9998610709,
#     'gr': 'S,ед,жен,неод=(пр|дат)'}],
#   'text': 'тишине'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'одиночество', 'wt': 1, 'gr': 'S,сред,неод=дат,ед'}],
#   'text': 'одиночеству'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'и', 'wt': 0.9999770357, 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'снимать', 'wt': 1, 'gr': 'V,пе=прош,деепр,сов'}],
#   'text': 'сняв'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'голова',
#     'wt': 0.9999566858,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'головы'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'старый', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'старую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'солдатский', 'wt': 1, 'gr': 'A=вин,ед,полн,жен'}],
#   'text': 'солдатскую'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ушанка', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'ушанку'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'сушить', 'wt': 1, 'gr': 'V,несов,пе=инф'}],
#   'text': 'сушить'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ветерок', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'ветерке'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мокрый',
#     'wt': 1,
#     'gr': 'A=(вин,мн,полн,неод|им,мн,полн)'}],
#   'text': 'мокрые'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'тяжелый',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'тяжелой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'гребля',
#     'wt': 0.8303981643,
#     'gr': 'S,жен,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'гребли'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'волос',
#     'wt': 0.9993213666,
#     'gr': 'S,муж,неод=(вин,мн|им,мн)'}],
#   'text': 'волосы'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'бездумно', 'wt': 0.9674687911, 'gr': 'ADV='}],
#   'text': 'бездумно'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'следить', 'wt': 1, 'gr': 'V,несов,нп=инф'}],
#   'text': 'следить'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'проплывать',
#     'wt': 1,
#     'gr': 'V,пе=непрош,твор,мн,прич,полн,несов,действ'}],
#   'text': 'проплывающими'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'блеклый',
#     'wt': 1,
#     'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#   'text': 'блеклой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'синева', 'wt': 1, 'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'синеве'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'белый', 'wt': 0.9932845421, 'gr': 'A=твор,мн,полн'}],
#   'text': 'белыми'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'грудастый', 'wt': 1, 'gr': 'A=твор,мн,полн'}],
#   'text': 'грудастыми'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'облако', 'wt': 1, 'gr': 'S,сред,неод=твор,мн'}],
#   'text': 'облаками'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'вскоре', 'wt': 1, 'gr': 'ADV='}], 'text': 'Вскоре'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'увидеть',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'увидел'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'из-за', 'wt': 1, 'gr': 'PR='}], 'text': 'из-за'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'крайний',
#     'wt': 1,
#     'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#   'text': 'крайних'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'двор', 'wt': 0.9956390193, 'gr': 'S,муж,неод=род,мн'}],
#   'text': 'дворов'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'хутор',
#     'wt': 1,
#     'gr': 'S,муж,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'хутора'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'выходить',
#     'wt': 0.9509142232,
#     'gr': 'V,нп=прош,ед,изъяв,муж,сов'}],
#   'text': 'вышел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'дорога', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'дорогу'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мужчина', 'wt': 1, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'мужчина'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вести',
#     'wt': 1,
#     'gr': 'V,несов,пе=прош,ед,изъяв,муж'}],
#   'text': 'вел'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'рука', 'wt': 1, 'gr': 'S,жен,неод=вин,ед'}],
#   'text': 'руку'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'маленький',
#     'wt': 0.999475298,
#     'gr': 'A=(вин,ед,полн,муж,од|род,ед,полн,муж|род,ед,полн,сред)'}],
#   'text': 'маленького'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мальчик', 'wt': 1, 'gr': 'S,муж,од=(вин,ед|род,ед)'}],
#   'text': 'мальчика'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'судя', 'wt': 0.9476349558, 'gr': 'ADV='}],
#   'text': 'судя'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'рост', 'wt': 1, 'gr': 'S,муж,неод=(дат,ед|парт,ед)'}],
#   'text': 'росту'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'год', 'wt': 0.9954891636, 'gr': 'S,муж,неод=род,мн'}],
#   'text': 'лет'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пять', 'wt': 1, 'gr': 'NUM=(пр|дат|род)'}],
#   'text': 'пяти'},
#  {'text': '-'},
#  {'analysis': [{'lex': 'шесть', 'wt': 1, 'gr': 'NUM=(пр|дат|род)'}],
#   'text': 'шести'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'много', 'wt': 0.0002164204767, 'gr': 'ADV=срав'}],
#   'text': 'больше'},
#  {'text': '.'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'устало', 'wt': 0.7728243313, 'gr': 'ADV='}],
#   'text': 'устало'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'брести', 'wt': 1, 'gr': 'V,несов,нп=прош,мн,изъяв'}],
#   'text': 'брели'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'направление', 'wt': 1, 'gr': 'S,сред,неод=дат,ед'}],
#   'text': 'направлению'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'переправа',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|дат,ед)'}],
#   'text': 'переправе'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'но', 'wt': 0.9998906299, 'gr': 'CONJ='}],
#   'text': 'но'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'поравняться', 'wt': 1, 'gr': 'V,сов,нп=прош,деепр'}],
#   'text': 'поравнявшись'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'машина',
#     'wt': 0.9996716856,
#     'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'машиной'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'повертывать', 'wt': 1, 'gr': 'V=прош,мн,изъяв,сов'}],
#   'text': 'повернули'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'ко', 'wt': 1, 'gr': 'PR='}], 'text': 'ко'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'я', 'wt': 1, 'gr': 'SPRO,ед,1-л=(пр|дат)'}],
#   'text': 'мне'},
#  {'text': '. '},
#  {'analysis': [{'lex': 'высокий',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'Высокий'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'сутуловатый',
#     'wt': 1,
#     'gr': 'A=(вин,ед,полн,муж,неод|им,ед,полн,муж)'}],
#   'text': 'сутуловатый'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мужчина', 'wt': 1, 'gr': 'S,муж,од=им,ед'}],
#   'text': 'мужчина'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'подходить', 'wt': 1, 'gr': 'V,нп=прош,деепр,сов'}],
#   'text': 'подойдя'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вплотную', 'wt': 1, 'gr': 'ADV='}],
#   'text': 'вплотную'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'сказать',
#     'wt': 1,
#     'gr': 'V,сов,пе=прош,ед,изъяв,муж'}],
#   'text': 'сказал'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'приглушенный',
#     'wt': 0.06879395168,
#     'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#   'text': 'приглушенным'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'басок',
#     'wt': 0.6717365591,
#     'gr': 'S,муж,неод=твор,ед'}],
#   'text': 'баском'},
#  {'text': ':\n'}]

# %%
import re 
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, STOPWORDS 

text = re.sub(r'==.*?==+', '', filtered_text) 
text = text.replace('\n', '') 
# Define a function to plot word cloud 
def plot_cloud(wordcloud): 
    # Set figure size 
    plt.figure(figsize=(40, 30)) 
    # Display image 
    plt.imshow(wordcloud)  
    # No axis details 
    plt.axis("off") 
# Generate word cloud 
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate(filtered_text)
plot_cloud(wordcloud)
