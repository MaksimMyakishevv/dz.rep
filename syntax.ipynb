# %% [markdown]
# # Cинтаксический анализ текста
#
# Синтаксический анализ текста на русском языке с использованием библиотек:
# - [spaCy](https://spacy.io).
# - [Natasha](https://github.com/natasha/natasha).

# %%
import spacy
from spacy import displacy

# %% [markdown]
# ## Библиотека spaCy
# python -m spacy download ru_core_news_sm

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
text = '''А тут вот она, война. На второй день повестка из военкомата, а на третий — пожалуйте в эшелон. Провожали меня все четверо моих: Ирина, Анатолий и дочери — Настенька и Олюшка. Все ребята держались молодцом. Ну, у дочерей — не без того, посверкивали слезинки. Анатолий только плечами передергивал, как от холода, ему к тому времени уже семнадцатый год шел, а Ирина моя… Такой я ее за все семнадцать лет нашей совместной жизни ни разу не видал. Ночью у меня на плече и на груди рубаха от ее слез не просыхала, и утром такая же история… Пришли на вокзал, а я на нее от жалости глядеть не могу: губы от слез распухли, волосы из-под платка выбились, и глаза мутные, несмысленные, как у тронутого умом человека. Командиры объявляют посадку, а она упала мне на грудь, руки на моей шее сцепила и вся дрожит, будто подрубленное дерево… И детишки ее уговаривают, и я, — ничего не помогает! Другие женщины с мужьями, с сыновьями разговаривают, а моя прижалась ко мне, как лист к ветке, и только вся дрожит, а слова вымолвить не может. Я и говорю ей: «Возьми же себя в руки, милая моя Иринка! Скажи мне хоть слово на прощанье». Она и говорит, и за каждым словом всхлипывает: «Родненький мой… Андрюша… не увидимся мы с тобой… больше… на этом… свете»…

Тут у самого от жалости к ней сердце на части разрывается, а тут она с такими словами. Должна бы понимать, что мне тоже нелегко с ними расставаться, не к теще на блины собрался. Зло меня тут взяло! Силой я разнял ее руки и легонько толкнул в плечи. Толкнул вроде легонько, а сила-то у меня была дурачья; она попятилась, шага три ступнула назад и опять ко мне идет мелкими шажками, руки протягивает, а я кричу ей: «Да разве же так прощаются? Что ты меня раньше времени заживо хоронишь?!» Ну, опять обнял ее, вижу, что она не в себе…'''

# %%
doc = nlp(text)

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# А CCONJ cc
# тут ADV ROOT
# вот PART advmod
# она PRON nsubj
# , PUNCT punct
# война NOUN conj
# . PUNCT punct
# На ADP case
# второй ADJ amod
# день NOUN ROOT
# повестка NOUN nmod
# из ADP case
# военкомата NOUN nmod
# , PUNCT punct
# а CCONJ cc
# на ADP case
# третий ADJ obl
# — PUNCT punct
# пожалуйте VERB conj
# в ADP case
# эшелон NOUN obl
# . PUNCT punct
# Провожали VERB ROOT
# меня PRON obj
# все DET det
# четверо NUM nummod:gov
# моих DET nsubj
# : PUNCT punct
# Ирина PROPN parataxis
# , PUNCT punct
# Анатолий PROPN conj
# и CCONJ cc
# дочери NOUN conj
# — PUNCT punct
# Настенька PROPN conj
# и CCONJ cc
# Олюшка PROPN conj
# . PUNCT punct
# Все DET det
# ребята NOUN nsubj
# держались VERB ROOT
# молодцом NOUN obl
# . PUNCT punct
# Ну PART discourse
# , PUNCT punct
# у ADP case
# дочерей NOUN ROOT
# — PUNCT punct
# не PART advmod
# без ADP case
# того PRON parataxis
# , PUNCT punct
# посверкивали VERB parataxis
# слезинки NOUN obj
# . PUNCT punct
# Анатолий PROPN nsubj
# только PART advmod
# плечами NOUN obl
# передергивал VERB ROOT
# , PUNCT punct
# как SCONJ case
# от ADP case
# холода NOUN obl
# , PUNCT punct
# ему PRON iobj
# к ADP case
# тому DET det
# времени NOUN obl
# уже ADV advmod
# семнадцатый VERB amod
# год NOUN obl
# шел VERB ccomp
# , PUNCT punct
# а CCONJ cc
# Ирина PROPN conj
# моя DET det
# … PUNCT punct
# Такой DET det
# я PRON nsubj
# ее PRON obj
# за ADP case
# все DET det
# семнадцать NUM nummod:gov
# лет NOUN obl
# нашей DET det
# совместной ADJ amod
# жизни NOUN nmod
# ни PART advmod
# разу NOUN obl
# не PART advmod
# видал VERB ROOT
# . PUNCT punct
# Ночью NOUN obl
# у ADP case
# меня PRON obl
# на ADP case
# плече NOUN obl
# и CCONJ cc
# на ADP case
# груди NOUN conj
# рубаха NOUN nmod
# от ADP case
# ее DET det
# слез NOUN obl
# не PART advmod
# просыхала VERB ROOT
# , PUNCT punct
# и CCONJ cc
# утром NOUN mark
# такая DET det
# же PART advmod
# история NOUN conj
# … PUNCT punct
# Пришли VERB ROOT
# на ADP case
# вокзал NOUN obl
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# на ADP case
# нее PRON obl
# от ADP case
# жалости NOUN obl
# глядеть VERB xcomp
# не PART advmod
# могу VERB conj
# : PUNCT punct
# губы NOUN nsubj
# от ADP case
# слез NOUN nmod
# распухли NOUN parataxis
# , PUNCT punct
# волосы NOUN nsubj
# из ADP case
# - ADP case
# под ADP case
# платка NOUN obl
# выбились VERB conj
# , PUNCT punct
# и CCONJ cc
# глаза NOUN nsubj
# мутные ADJ conj
# , PUNCT punct
# несмысленные ADJ conj
# , PUNCT punct
# как SCONJ case
# у ADP case
# тронутого ADJ amod
# умом NOUN obl
# человека NOUN nmod
# . PUNCT punct
# Командиры NOUN nsubj
# объявляют VERB ROOT
# посадку NOUN obj
# , PUNCT punct
# а CCONJ cc
# она PRON nsubj
# упала VERB conj
# мне PRON iobj
# на ADP case
# грудь NOUN obl
# , PUNCT punct
# руки NOUN obj
# на ADP case
# моей DET det
# шее NOUN obl
# сцепила VERB conj
# и CCONJ cc
# вся DET nsubj
# дрожит VERB conj
# , PUNCT punct
# будто SCONJ mark
# подрубленное ADJ amod
# дерево NOUN advcl
# … PUNCT punct
# И CCONJ cc
# детишки NOUN nsubj
# ее PRON obj
# уговаривают VERB ROOT
# , PUNCT punct
# и CCONJ cc
# я PRON nsubj
# , PUNCT punct
# — PUNCT punct
# ничего PRON nsubj
# не PART advmod
# помогает VERB conj
# ! PUNCT punct
# Другие ADJ amod
# женщины NOUN nsubj
# с ADP case
# мужьями NOUN nmod
# , PUNCT punct
# с ADP case
# сыновьями NOUN obl
# разговаривают VERB ROOT
# , PUNCT punct
# а CCONJ cc
# моя DET nsubj
# прижалась VERB conj
# ко ADP case
# мне PRON obl
# , PUNCT punct
# как SCONJ case
# лист NOUN obl
# к ADP case
# ветке NOUN nmod
# , PUNCT punct
# и CCONJ cc
# только PART advmod
# вся DET nsubj
# дрожит VERB conj
# , PUNCT punct
# а CCONJ cc
# слова NOUN obj
# вымолвить VERB xcomp
# не PART advmod
# может VERB conj
# . PUNCT punct
# Я PRON nsubj
# и PART advmod
# говорю VERB ROOT
# ей PRON iobj
# : PUNCT punct
# « PUNCT punct
# Возьми VERB parataxis
# же PART advmod
# себя PRON obj
# в ADP case
# руки NOUN obl
# , PUNCT punct
# милая ADJ amod
# моя DET det
# Иринка PROPN nsubj
# ! PUNCT punct
# Скажи VERB ROOT
# мне PRON iobj
# хоть ADV advmod
# слово NOUN obj
# на ADP case
# прощанье NOUN nmod
# » PUNCT punct
# . PUNCT punct
# Она PRON nsubj
# и PART advmod
# говорит VERB ROOT
# , PUNCT punct
# и CCONJ cc
# за ADP case
# каждым DET det
# словом NOUN obl
# всхлипывает VERB conj
# : PUNCT punct
# « PUNCT punct
# Родненький ADJ amod
# мой DET parataxis
# … PUNCT punct
# Андрюша NOUN obl
# … PUNCT punct
# не PART advmod
# увидимся VERB ROOT
# мы PRON nsubj
# с ADP case
# тобой PRON obl
# … PUNCT punct
# больше NUM ROOT
# … PUNCT punct
# на ADP case
# этом PRON obl
# … PUNCT punct
# свете VERB ROOT
# » PUNCT punct
# … PUNCT punct
#
#
#  SPACE dep
# Тут ADV advmod
# у ADP case
# самого ADJ obl
# от ADP case
# жалости NOUN nmod
# к ADP case
# ней PRON nmod
# сердце NOUN nsubj
# на ADP case
# части NOUN obl
# разрывается VERB ROOT
# , PUNCT punct
# а CCONJ cc
# тут ADV advmod
# она PRON nsubj
# с ADP case
# такими DET det
# словами NOUN conj
# . PUNCT punct
# Должна ADJ ROOT
# бы AUX aux
# понимать VERB xcomp
# , PUNCT punct
# что SCONJ mark
# мне PRON iobj
# тоже ADV advmod
# нелегко ADJ ccomp
# с ADP case
# ними PRON obl
# расставаться VERB csubj
# , PUNCT punct
# не PART advmod
# к ADP case
# теще NOUN obl
# на ADP case
# блины NOUN obl
# собрался VERB conj
# . PUNCT punct
# Зло NOUN nsubj
# меня PRON obj
# тут ADV advmod
# взяло VERB ROOT
# ! PUNCT punct
# Силой NOUN obl
# я PRON nsubj
# разнял VERB ROOT
# ее DET det
# руки NOUN obj
# и CCONJ cc
# легонько ADV advmod
# толкнул VERB conj
# в ADP case
# плечи NOUN obl
# . PUNCT punct
# Толкнул VERB ROOT
# вроде ADP case
# легонько ADV obl
# , PUNCT punct
# а CCONJ cc
# сила NOUN conj
# - NOUN nsubj
# то ADV advmod
# у ADP case
# меня PRON obl
# была VERB conj
# дурачья NOUN nsubj
# ; PUNCT punct
# она PRON nsubj
# попятилась VERB conj
# , PUNCT punct
# шага NOUN nsubj
# три NUM nummod:gov
# ступнула VERB conj
# назад ADV advmod
# и CCONJ cc
# опять ADV advmod
# ко ADP case
# мне PRON obl
# идет VERB conj
# мелкими ADJ amod
# шажками NOUN obl
# , PUNCT punct
# руки NOUN obj
# протягивает VERB conj
# , PUNCT punct
# а CCONJ cc
# я PRON nsubj
# кричу VERB conj
# ей PRON iobj
# : PUNCT punct
# « PUNCT punct
# Да PART advmod
# разве PART advmod
# же PART advmod
# так ADV advmod
# прощаются VERB parataxis
# ? PUNCT punct
# Что PRON obj
# ты PRON nsubj
# меня PRON obj
# раньше ADV advmod
# времени NOUN obj
# заживо ADV advmod
# хоронишь VERB ROOT
# ? PUNCT punct
# ! PUNCT punct
# » PUNCT punct
# Ну PART discourse
# , PUNCT punct
# опять ADV advmod
# обнял VERB ROOT
# ее PRON obj
# , PUNCT punct
# вижу VERB conj
# , PUNCT punct
# что SCONJ mark
# она PRON nsubj
# не PART advmod
# в ADP case
# себе PRON ccomp
# … PUNCT punct

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="f6cf6deb93c742b5b9496debcc412405-0" class="displacy" width="54825" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">А</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">тут</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">вот</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">она,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">война.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">На</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">второй</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">день</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">повестка</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">из</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">военкомата,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">а</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">на</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">третий —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">пожалуйте</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">в</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">эшелон.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Провожали</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">меня</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">все</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">четверо</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">моих:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Ирина,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Анатолий</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">дочери —</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Настенька</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">и</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">Олюшка.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">Все</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">ребята</tspan>
#     <tspan class="displacy-tag" dy="2em" fill

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp(u'We can overtake them.')
doc2 = nlp(u'You must specify it.')
for i in range(len(doc1)-1):
    if doc1[i].dep_ == doc2[i].dep_:
        print(doc1[i].text,'\t', doc2[i].text, '\t', doc1[i].dep_, spacy.explain(doc1[i].dep_))
# Out:
# We 	 You 	 nsubj nominal subject
# can 	 must 	 aux auxiliary
# overtake 	 specify 	 ROOT root
# them 	 it 	 dobj direct object

# %% [markdown]
# ## Библиотека natasha

# %%
from natasha import Segmenter, NewsEmbedding, NewsSyntaxParser, Doc

# %%
emb = NewsEmbedding()

# %%
segmenter = Segmenter()

# %%
syntax_parser = NewsSyntaxParser(emb)

# %%
text = '''А тут вот она, война. На второй день повестка из военкомата, а на третий — пожалуйте в эшелон. Провожали меня все четверо моих: Ирина, Анатолий и дочери — Настенька и Олюшка. Все ребята держались молодцом. Ну, у дочерей — не без того, посверкивали слезинки. Анатолий только плечами передергивал, как от холода, ему к тому времени уже семнадцатый год шел, а Ирина моя… Такой я ее за все семнадцать лет нашей совместной жизни ни разу не видал. Ночью у меня на плече и на груди рубаха от ее слез не просыхала, и утром такая же история… Пришли на вокзал, а я на нее от жалости глядеть не могу: губы от слез распухли, волосы из-под платка выбились, и глаза мутные, несмысленные, как у тронутого умом человека. Командиры объявляют посадку, а она упала мне на грудь, руки на моей шее сцепила и вся дрожит, будто подрубленное дерево… И детишки ее уговаривают, и я, — ничего не помогает! Другие женщины с мужьями, с сыновьями разговаривают, а моя прижалась ко мне, как лист к ветке, и только вся дрожит, а слова вымолвить не может. Я и говорю ей: «Возьми же себя в руки, милая моя Иринка! Скажи мне хоть слово на прощанье». Она и говорит, и за каждым словом всхлипывает: «Родненький мой… Андрюша… не увидимся мы с тобой… больше… на этом… свете»…

Тут у самого от жалости к ней сердце на части разрывается, а тут она с такими словами. Должна бы понимать, что мне тоже нелегко с ними расставаться, не к теще на блины собрался. Зло меня тут взяло! Силой я разнял ее руки и легонько толкнул в плечи. Толкнул вроде легонько, а сила-то у меня была дурачья; она попятилась, шага три ступнула назад и опять ко мне идет мелкими шажками, руки протягивает, а я кричу ей: «Да разве же так прощаются? Что ты меня раньше времени заживо хоронишь?!» Ну, опять обнял ее, вижу, что она не в себе…'''

# %%
doc = Doc(text)

# %%
doc.segment(segmenter)

# %%
for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(stop=1, text='А')
# DocToken(start=2, stop=5, text='тут')
# DocToken(start=6, stop=9, text='вот')
# DocToken(start=10, stop=13, text='она')
# DocToken(start=13, stop=14, text=',')
# DocToken(start=15, stop=20, text='война')
# DocToken(start=20, stop=21, text='.')
# DocToken(start=22, stop=24, text='На')
# DocToken(start=25, stop=31, text='второй')
# DocToken(start=32, stop=36, text='день')
# DocToken(start=37, stop=45, text='повестка')
# DocToken(start=46, stop=48, text='из')
# DocToken(start=49, stop=59, text='военкомата')
# DocToken(start=59, stop=60, text=',')
# DocToken(start=61, stop=62, text='а')
# DocToken(start=63, stop=65, text='на')
# DocToken(start=66, stop=72, text='третий')
# DocToken(start=73, stop=74, text='—')
# DocToken(start=75, stop=84, text='пожалуйте')
# DocToken(start=85, stop=86, text='в')
# DocToken(start=87, stop=93, text='эшелон')
# DocToken(start=93, stop=94, text='.')
# DocToken(start=95, stop=104, text='Провожали')
# DocToken(start=105, stop=109, text='меня')
# DocToken(start=110, stop=113, text='все')
# DocToken(start=114, stop=121, text='четверо')
# DocToken(start=122, stop=126, text='моих')
# DocToken(start=126, stop=127, text=':')
# DocToken(start=128, stop=133, text='Ирина')
# DocToken(start=133, stop=134, text=',')
# DocToken(start=135, stop=143, text='Анатолий')
# DocToken(start=144, stop=145, text='и')
# DocToken(start=146, stop=152, text='дочери')
# DocToken(start=153, stop=154, text='—')
# DocToken(start=155, stop=164, text='Настенька')
# DocToken(start=165, stop=166, text='и')
# DocToken(start=167, stop=173, text='Олюшка')
# DocToken(start=173, stop=174, text='.')
# DocToken(start=175, stop=178, text='Все')
# DocToken(start=179, stop=185, text='ребята')
# DocToken(start=186, stop=195, text='держались')
# DocToken(start=196, stop=204, text='молодцом')
# DocToken(start=204, stop=205, text='.')
# DocToken(start=206, stop=208, text='Ну')
# DocToken(start=208, stop=209, text=',')
# DocToken(start=210, stop=211, text='у')
# DocToken(start=212, stop=219, text='дочерей')
# DocToken(start=220, stop=221, text='—')
# DocToken(start=222, stop=224, text='не')
# DocToken(start=225, stop=228, text='без')
# DocToken(start=229, stop=233, text='того')
# DocToken(start=233, stop=234, text=',')
# DocToken(start=235, stop=247, text='посверкивали')
# DocToken(start=248, stop=256, text='слезинки')
# DocToken(start=256, stop=257, text='.')
# DocToken(start=258, stop=266, text='Анатолий')
# DocToken(start=267, stop=273, text='только')
# DocToken(start=274, stop=281, text='плечами')
# DocToken(start=282, stop=294, text='передергивал')
# DocToken(start=294, stop=295, text=',')
# DocToken(start=296, stop=299, text='как')
# DocToken(start=300, stop=302, text='от')
# DocToken(start=303, stop=309, text='холода')
# DocToken(start=309, stop=310, text=',')
# DocToken(start=311, stop=314, text='ему')
# DocToken(start=315, stop=316, text='к')
# DocToken(start=317, stop=321, text='тому')
# DocToken(start=322, stop=329, text='времени')
# DocToken(start=330, stop=333, text='уже')
# DocToken(start=334, stop=345, text='семнадцатый')
# DocToken(start=346, stop=349, text='год')
# DocToken(start=350, stop=353, text='шел')
# DocToken(start=353, stop=354, text=',')
# DocToken(start=355, stop=356, text='а')
# DocToken(start=357, stop=362, text='Ирина')
# DocToken(start=363, stop=366, text='моя')
# DocToken(start=366, stop=367, text='…')
# DocToken(start=368, stop=373, text='Такой')
# DocToken(start=374, stop=375, text='я')
# DocToken(start=376, stop=378, text='ее')
# DocToken(start=379, stop=381, text='за')
# DocToken(start=382, stop=385, text='все')
# DocToken(start=386, stop=396, text='семнадцать')
# DocToken(start=397, stop=400, text='лет')
# DocToken(start=401, stop=406, text='нашей')
# DocToken(start=407, stop=417, text='совместной')
# DocToken(start=418, stop=423, text='жизни')
# DocToken(start=424, stop=426, text='ни')
# DocToken(start=427, stop=431, text='разу')
# DocToken(start=432, stop=434, text='не')
# DocToken(start=435, stop=440, text='видал')
# DocToken(start=440, stop=441, text='.')
# DocToken(start=442, stop=447, text='Ночью')
# DocToken(start=448, stop=449, text='у')
# DocToken(start=450, stop=454, text='меня')
# DocToken(start=455, stop=457, text='на')
# DocToken(start=458, stop=463, text='плече')
# DocToken(start=464, stop=465, text='и')
# DocToken(start=466, stop=468, text='на')
# DocToken(start=469, stop=474, text='груди')
# DocToken(start=475, stop=481, text='рубаха')
# DocToken(start=482, stop=484, text='от')
# DocToken(start=485, stop=487, text='ее')
# DocToken(start=488, stop=492, text='слез')
# DocToken(start=493, stop=495, text='не')
# DocToken(start=496, stop=505, text='просыхала')
# DocToken(start=505, stop=506, text=',')
# DocToken(start=507, stop=508, text='и')
# DocToken(start=509, stop=514, text='утром')
# DocToken(start=515, stop=520, text='такая')
# DocToken(start=521, stop=523, text='же')
# DocToken(start=524, stop=531, text='история')
# DocToken(start=531, stop=532, text='…')
# DocToken(start=533, stop=539, text='Пришли')
# DocToken(start=540, stop=542, text='на')
# DocToken(start=543, stop=549, text='вокзал')
# DocToken(start=549, stop=550, text=',')
# DocToken(start=551, stop=552, text='а')
# DocToken(start=553, stop=554, text='я')
# DocToken(start=555, stop=557, text='на')
# DocToken(start=558, stop=561, text='нее')
# DocToken(start=562, stop=564, text='от')
# DocToken(start=565, stop=572, text='жалости')
# DocToken(start=573, stop=580, text='глядеть')
# DocToken(start=581, stop=583, text='не')
# DocToken(start=584, stop=588, text='могу')
# DocToken(start=588, stop=589, text=':')
# DocToken(start=590, stop=594, text='губы')
# DocToken(start=595, stop=597, text='от')
# DocToken(start=598, stop=602, text='слез')
# DocToken(start=603, stop=611, text='распухли')
# DocToken(start=611, stop=612, text=',')
# DocToken(start=613, stop=619, text='волосы')
# DocToken(start=620, stop=626, text='из-под')
# DocToken(start=627, stop=633, text='платка')
# DocToken(start=634, stop=642, text='выбились')
# DocToken(start=642, stop=643, text=',')
# DocToken(start=644, stop=645, text='и')
# DocToken(start=646, stop=651, text='глаза')
# DocToken(start=652, stop=658, text='мутные')
# DocToken(start=658, stop=659, text=',')
# DocToken(start=660, stop=672, text='несмысленные')
# DocToken(start=672, stop=673, text=',')
# DocToken(start=674, stop=677, text='как')
# DocToken(start=678, stop=679, text='у')
# DocToken(start=680, stop=689, text='тронутого')
# DocToken(start=690, stop=694, text='умом')
# DocToken(start=695, stop=703, text='человека')
# DocToken(start=703, stop=704, text='.')
# DocToken(start=705, stop=714, text='Командиры')
# DocToken(start=715, stop=724, text='объявляют')
# DocToken(start=725, stop=732, text='посадку')
# DocToken(start=732, stop=733, text=',')
# DocToken(start=734, stop=735, text='а')
# DocToken(start=736, stop=739, text='она')
# DocToken(start=740, stop=745, text='упала')
# DocToken(start=746, stop=749, text='мне')
# DocToken(start=750, stop=752, text='на')
# DocToken(start=753, stop=758, text='грудь')
# DocToken(start=758, stop=759, text=',')
# DocToken(start=760, stop=764, text='руки')
# DocToken(start=765, stop=767, text='на')
# DocToken(start=768, stop=772, text='моей')
# DocToken(start=773, stop=776, text='шее')
# DocToken(start=777, stop=784, text='сцепила')
# DocToken(start=785, stop=786, text='и')
# DocToken(start=787, stop=790, text='вся')
# DocToken(start=791, stop=797, text='дрожит')
# DocToken(start=797, stop=798, text=',')
# DocToken(start=799, stop=804, text='будто')
# DocToken(start=805, stop=817, text='подрубленное')
# DocToken(start=818, stop=824, text='дерево')
# DocToken(start=824, stop=825, text='…')
# DocToken(start=826, stop=827, text='И')
# DocToken(start=828, stop=835, text='детишки')
# DocToken(start=836, stop=838, text='ее')
# DocToken(start=839, stop=850, text='уговаривают')
# DocToken(start=850, stop=851, text=',')
# DocToken(start=852, stop=853, text='и')
# DocToken(start=854, stop=855, text='я')
# DocToken(start=855, stop=856, text=',')
# DocToken(start=857, stop=858, text='—')
# DocToken(start=859, stop=865, text='ничего')
# DocToken(start=866, stop=868, text='не')
# DocToken(start=869, stop=877, text='помогает')
# DocToken(start=877, stop=878, text='!')
# DocToken(start=879, stop=885, text='Другие')
# DocToken(start=886, stop=893, text='женщины')
# DocToken(start=894, stop=895, text='с')
# DocToken(start=896, stop=903, text='мужьями')
# DocToken(start=903, stop=904, text=',')
# DocToken(start=905, stop=906, text='с')
# DocToken(start=907, stop=916, text='сыновьями')
# DocToken(start=917, stop=930, text='разговаривают')
# DocToken(start=930, stop=931, text=',')
# DocToken(start=932, stop=933, text='а')
# DocToken(start=934, stop=937, text='моя')
# DocToken(start=938, stop=947, text='прижалась')
# DocToken(start=948, stop=950, text='ко')
# DocToken(start=951, stop=954, text='мне')
# DocToken(start=954, stop=955, text=',')
# DocToken(start=956, stop=959, text='как')
# DocToken(start=960, stop=964, text='лист')
# DocToken(start=965, stop=966, text='к')
# DocToken(start=967, stop=972, text='ветке')
# DocToken(start=972, stop=973, text=',')
# DocToken(start=974, stop=975, text='и')
# DocToken(start=976, stop=982, text='только')
# DocToken(start=983, stop=986, text='вся')
# DocToken(start=987, stop=993, text='дрожит')
# DocToken(start=993, stop=994, text=',')
# DocToken(start=995, stop=996, text='а')
# DocToken(start=997, stop=1002, text='слова')
# DocToken(start=1003, stop=1012, text='вымолвить')
# DocToken(start=1013, stop=1015, text='не')
# DocToken(start=1016, stop=1021, text='может')
# DocToken(start=1021, stop=1022, text='.')
# DocToken(start=1023, stop=1024, text='Я')
# DocToken(start=1025, stop=1026, text='и')
# DocToken(start=1027, stop=1033, text='говорю')
# DocToken(start=1034, stop=1036, text='ей')
# DocToken(start=1036, stop=1037, text=':')
# DocToken(start=1038, stop=1039, text='«')
# DocToken(start=1039, stop=1045, text='Возьми')
# DocToken(start=1046, stop=1048, text='же')
# DocToken(start=1049, stop=1053, text='себя')
# DocToken(start=1054, stop=1055, text='в')
# DocToken(start=1056, stop=1060, text='руки')
# DocToken(start=1060, stop=1061, text=',')
# DocToken(start=1062, stop=1067, text='милая')
# DocToken(start=1068, stop=1071, text='моя')
# DocToken(start=1072, stop=1078, text='Иринка')
# DocToken(start=1078, stop=1079, text='!')
# DocToken(start=1080, stop=1085, text='Скажи')
# DocToken(start=1086, stop=1089, text='мне')
# DocToken(start=1090, stop=1094, text='хоть')
# DocToken(start=1095, stop=1100, text='слово')
# DocToken(start=1101, stop=1103, text='на')
# DocToken(start=1104, stop=1112, text='прощанье')
# DocToken(start=1112, stop=1113, text='»')
# DocToken(start=1113, stop=1114, text='.')
# DocToken(start=1115, stop=1118, text='Она')
# DocToken(start=1119, stop=1120, text='и')
# DocToken(start=1121, stop=1128, text='говорит')
# DocToken(start=1128, stop=1129, text=',')
# DocToken(start=1130, stop=1131, text='и')
# DocToken(start=1132, stop=1134, text='за')
# DocToken(start=1135, stop=1141, text='каждым')
# DocToken(start=1142, stop=1148, text='словом')
# DocToken(start=1149, stop=1160, text='всхлипывает')
# DocToken(start=1160, stop=1161, text=':')
# DocToken(start=1162, stop=1163, text='«')
# DocToken(start=1163, stop=1173, text='Родненький')
# DocToken(start=1174, stop=1177, text='мой')
# DocToken(start=1177, stop=1178, text='…')
# DocToken(start=1179, stop=1186, text='Андрюша')
# DocToken(start=1186, stop=1187, text='…')
# DocToken(start=1188, stop=1190, text='не')
# DocToken(start=1191, stop=1199, text='увидимся')
# DocToken(start=1200, stop=1202, text='мы')
# DocToken(start=1203, stop=1204, text='с')
# DocToken(start=1205, stop=1210, text='тобой')
# DocToken(start=1210, stop=1211, text='…')
# DocToken(start=1212, stop=1218, text='больше')
# DocToken(start=1218, stop=1219, text='…')
# DocToken(start=1220, stop=1222, text='на')
# DocToken(start=1223, stop=1227, text='этом')
# DocToken(start=1227, stop=1228, text='…')
# DocToken(start=1229, stop=1234, text='свете')
# DocToken(start=1234, stop=1235, text='»')
# DocToken(start=1235, stop=1236, text='…')
# DocToken(start=1238, stop=1241, text='Тут')
# DocToken(start=1242, stop=1243, text='у')
# DocToken(start=1244, stop=1250, text='самого')
# DocToken(start=1251, stop=1253, text='от')
# DocToken(start=1254, stop=1261, text='жалости')
# DocToken(start=1262, stop=1263, text='к')
# DocToken(start=1264, stop=1267, text='ней')
# DocToken(start=1268, stop=1274, text='сердце')
# DocToken(start=1275, stop=1277, text='на')
# DocToken(start=1278, stop=1283, text='части')
# DocToken(start=1284, stop=1295, text='разрывается')
# DocToken(start=1295, stop=1296, text=',')
# DocToken(start=1297, stop=1298, text='а')
# DocToken(start=1299, stop=1302, text='тут')
# DocToken(start=1303, stop=1306, text='она')
# DocToken(start=1307, stop=1308, text='с')
# DocToken(start=1309, stop=1315, text='такими')
# DocToken(start=1316, stop=1323, text='словами')
# DocToken(start=1323, stop=1324, text='.')
# DocToken(start=1325, stop=1331, text='Должна')
# DocToken(start=1332, stop=1334, text='бы')
# DocToken(start=1335, stop=1343, text='понимать')
# DocToken(start=1343, stop=1344, text=',')
# DocToken(start=1345, stop=1348, text='что')
# DocToken(start=1349, stop=1352, text='мне')
# DocToken(start=1353, stop=1357, text='тоже')
# DocToken(start=1358, stop=1365, text='нелегко')
# DocToken(start=1366, stop=1367, text='с')
# DocToken(start=1368, stop=1372, text='ними')
# DocToken(start=1373, stop=1385, text='расставаться')
# DocToken(start=1385, stop=1386, text=',')
# DocToken(start=1387, stop=1389, text='не')
# DocToken(start=1390, stop=1391, text='к')
# DocToken(start=1392, stop=1396, text='теще')
# DocToken(start=1397, stop=1399, text='на')
# DocToken(start=1400, stop=1405, text='блины')
# DocToken(start=1406, stop=1414, text='собрался')
# DocToken(start=1414, stop=1415, text='.')
# DocToken(start=1416, stop=1419, text='Зло')
# DocToken(start=1420, stop=1424, text='меня')
# DocToken(start=1425, stop=1428, text='тут')
# DocToken(start=1429, stop=1434, text='взяло')
# DocToken(start=1434, stop=1435, text='!')
# DocToken(start=1436, stop=1441, text='Силой')
# DocToken(start=1442, stop=1443, text='я')
# DocToken(start=1444, stop=1450, text='разнял')
# DocToken(start=1451, stop=1453, text='ее')
# DocToken(start=1454, stop=1458, text='руки')
# DocToken(start=1459, stop=1460, text='и')
# DocToken(start=1461, stop=1469, text='легонько')
# DocToken(start=1470, stop=1477, text='толкнул')
# DocToken(start=1478, stop=1479, text='в')
# DocToken(start=1480, stop=1485, text='плечи')
# DocToken(start=1485, stop=1486, text='.')
# DocToken(start=1487, stop=1494, text='Толкнул')
# DocToken(start=1495, stop=1500, text='вроде')
# DocToken(start=1501, stop=1509, text='легонько')
# DocToken(start=1509, stop=1510, text=',')
# DocToken(start=1511, stop=1512, text='а')
# DocToken(start=1513, stop=1520, text='сила-то')
# DocToken(start=1521, stop=1522, text='у')
# DocToken(start=1523, stop=1527, text='меня')
# DocToken(start=1528, stop=1532, text='была')
# DocToken(start=1533, stop=1540, text='дурачья')
# DocToken(start=1540, stop=1541, text=';')
# DocToken(start=1542, stop=1545, text='она')
# DocToken(start=1546, stop=1556, text='попятилась')
# DocToken(start=1556, stop=1557, text=',')
# DocToken(start=1558, stop=1562, text='шага')
# DocToken(start=1563, stop=1566, text='три')
# DocToken(start=1567, stop=1575, text='ступнула')
# DocToken(start=1576, stop=1581, text='назад')
# DocToken(start=1582, stop=1583, text='и')
# DocToken(start=1584, stop=1589, text='опять')
# DocToken(start=1590, stop=1592, text='ко')
# DocToken(start=1593, stop=1596, text='мне')
# DocToken(start=1597, stop=1601, text='идет')
# DocToken(start=1602, stop=1609, text='мелкими')
# DocToken(start=1610, stop=1617, text='шажками')
# DocToken(start=1617, stop=1618, text=',')
# DocToken(start=1619, stop=1623, text='руки')
# DocToken(start=1624, stop=1635, text='протягивает')
# DocToken(start=1635, stop=1636, text=',')
# DocToken(start=1637, stop=1638, text='а')
# DocToken(start=1639, stop=1640, text='я')
# DocToken(start=1641, stop=1646, text='кричу')
# DocToken(start=1647, stop=1649, text='ей')
# DocToken(start=1649, stop=1650, text=':')
# DocToken(start=1651, stop=1652, text='«')
# DocToken(start=1652, stop=1654, text='Да')
# DocToken(start=1655, stop=1660, text='разве')
# DocToken(start=1661, stop=1663, text='же')
# DocToken(start=1664, stop=1667, text='так')
# DocToken(start=1668, stop=1677, text='прощаются')
# DocToken(start=1677, stop=1678, text='?')
# DocToken(start=1679, stop=1682, text='Что')
# DocToken(start=1683, stop=1685, text='ты')
# DocToken(start=1686, stop=1690, text='меня')
# DocToken(start=1691, stop=1697, text='раньше')
# DocToken(start=1698, stop=1705, text='времени')
# DocToken(start=1706, stop=1712, text='заживо')
# DocToken(start=1713, stop=1721, text='хоронишь')
# DocToken(start=1721, stop=1723, text='?!')
# DocToken(start=1723, stop=1724, text='»')
# DocToken(start=1725, stop=1727, text='Ну')
# DocToken(start=1727, stop=1728, text=',')
# DocToken(start=1729, stop=1734, text='опять')
# DocToken(start=1735, stop=1740, text='обнял')
# DocToken(start=1741, stop=1743, text='ее')
# DocToken(start=1743, stop=1744, text=',')
# DocToken(start=1745, stop=1749, text='вижу')
# DocToken(start=1749, stop=1750, text=',')
# DocToken(start=1751, stop=1754, text='что')
# DocToken(start=1755, stop=1758, text='она')
# DocToken(start=1759, stop=1761, text='не')
# DocToken(start=1762, stop=1763, text='в')
# DocToken(start=1764, stop=1768, text='себе')
# DocToken(start=1768, stop=1769, text='…')

# %%
doc.parse_syntax(syntax_parser)

# %%
for tocken in doc.tokens:
    print(tocken)
# Out:
# DocToken(stop=1, text='А', id='1_1', head_id='1_2', rel='cc')
# DocToken(start=2, stop=5, text='тут', id='1_2', head_id='1_2', rel='advmod')
# DocToken(start=6, stop=9, text='вот', id='1_3', head_id='1_2', rel='advmod')
# DocToken(start=10, stop=13, text='она', id='1_4', head_id='1_2', rel='nsubj')
# DocToken(start=13, stop=14, text=',', id='1_5', head_id='1_6', rel='punct')
# DocToken(start=15, stop=20, text='война', id='1_6', head_id='1_4', rel='conj')
# DocToken(start=20, stop=21, text='.', id='1_7', head_id='1_2', rel='punct')
# DocToken(start=22, stop=24, text='На', id='2_1', head_id='2_3', rel='case')
# DocToken(start=25, stop=31, text='второй', id='2_2', head_id='2_3', rel='amod')
# DocToken(start=32, stop=36, text='день', id='2_3', head_id='2_12', rel='obl')
# DocToken(start=37, stop=45, text='повестка', id='2_4', head_id='2_12', rel='nsubj')
# DocToken(start=46, stop=48, text='из', id='2_5', head_id='2_6', rel='case')
# DocToken(start=49, stop=59, text='военкомата', id='2_6', head_id='2_4', rel='nmod')
# DocToken(start=59, stop=60, text=',', id='2_7', head_id='2_12', rel='punct')
# DocToken(start=61, stop=62, text='а', id='2_8', head_id='2_12', rel='cc')
# DocToken(start=63, stop=65, text='на', id='2_9', head_id='2_10', rel='case')
# DocToken(start=66, stop=72, text='третий', id='2_10', head_id='2_12', rel='orphan')
# DocToken(start=73, stop=74, text='—', id='2_11', head_id='2_10', rel='punct')
# DocToken(start=75, stop=84, text='пожалуйте', id='2_12', head_id='2_10', rel='orphan')
# DocToken(start=85, stop=86, text='в', id='2_13', head_id='2_14', rel='case')
# DocToken(start=87, stop=93, text='эшелон', id='2_14', head_id='2_12', rel='obl')
# DocToken(start=93, stop=94, text='.', id='2_15', head_id='2_12', rel='punct')
# DocToken(start=95, stop=104, text='Провожали', id='3_1', head_id='3_0', rel='root')
# DocToken(start=105, stop=109, text='меня', id='3_2', head_id='3_1', rel='obj')
# DocToken(start=110, stop=113, text='все', id='3_3', head_id='3_4', rel='det')
# DocToken(start=114, stop=121, text='четверо', id='3_4', head_id='3_5', rel='nummod:gov')
# DocToken(start=122, stop=126, text='моих', id='3_5', head_id='3_5', rel='det')
# DocToken(start=126, stop=127, text=':', id='3_6', head_id='3_7', rel='punct')
# DocToken(start=128, stop=133, text='Ирина', id='3_7', head_id='3_5', rel='parataxis')
# DocToken(start=133, stop=134, text=',', id='3_8', head_id='3_9', rel='punct')
# DocToken(start=135, stop=143, text='Анатолий', id='3_9', head_id='3_7', rel='conj')
# DocToken(start=144, stop=145, text='и', id='3_10', head_id='3_11', rel='cc')
# DocToken(start=146, stop=152, text='дочери', id='3_11', head_id='3_7', rel='conj')
# DocToken(start=153, stop=154, text='—', id='3_12', head_id='3_13', rel='punct')
# DocToken(start=155, stop=164, text='Настенька', id='3_13', head_id='3_11', rel='appos')
# DocToken(start=165, stop=166, text='и', id='3_14', head_id='3_15', rel='cc')
# DocToken(start=167, stop=173, text='Олюшка', id='3_15', head_id='3_7', rel='conj')
# DocToken(start=173, stop=174, text='.', id='3_16', head_id='3_1', rel='punct')
# DocToken(start=175, stop=178, text='Все', id='4_1', head_id='4_2', rel='det')
# DocToken(start=179, stop=185, text='ребята', id='4_2', head_id='4_3', rel='nsubj')
# DocToken(start=186, stop=195, text='держались', id='4_3', head_id='4_0', rel='root')
# DocToken(start=196, stop=204, text='молодцом', id='4_4', head_id='4_3', rel='advmod')
# DocToken(start=204, stop=205, text='.', id='4_5', head_id='4_3', rel='punct')
# DocToken(start=206, stop=208, text='Ну', id='5_1', head_id='5_8', rel='parataxis')
# DocToken(start=208, stop=209, text=',', id='5_2', head_id='5_1', rel='punct')
# DocToken(start=210, stop=211, text='у', id='5_3', head_id='5_4', rel='case')
# DocToken(start=212, stop=219, text='дочерей', id='5_4', head_id='5_8', rel='conj')
# DocToken(start=220, stop=221, text='—', id='5_5', head_id='5_4', rel='punct')
# DocToken(start=222, stop=224, text='не', id='5_6', head_id='5_8', rel='advmod')
# DocToken(start=225, stop=228, text='без', id='5_7', head_id='5_8', rel='case')
# DocToken(start=229, stop=233, text='того', id='5_8', head_id='5_4', rel='orphan')
# DocToken(start=233, stop=234, text=',', id='5_9', head_id='5_10', rel='punct')
# DocToken(start=235, stop=247, text='посверкивали', id='5_10', head_id='5_4', rel='acl')
# DocToken(start=248, stop=256, text='слезинки', id='5_11', head_id='5_10', rel='obj')
# DocToken(start=256, stop=257, text='.', id='5_12', head_id='5_10', rel='punct')
# DocToken(start=258, stop=266, text='Анатолий', id='6_1', head_id='6_17', rel='nsubj')
# DocToken(start=267, stop=273, text='только', id='6_2', head_id='6_3', rel='advmod')
# DocToken(start=274, stop=281, text='плечами', id='6_3', head_id='6_17', rel='nsubj')
# DocToken(start=282, stop=294, text='передергивал', id='6_4', head_id='6_3', rel='nmod')
# DocToken(start=294, stop=295, text=',', id='6_5', head_id='6_8', rel='punct')
# DocToken(start=296, stop=299, text='как', id='6_6', head_id='6_8', rel='case')
# DocToken(start=300, stop=302, text='от', id='6_7', head_id='6_8', rel='case')
# DocToken(start=303, stop=309, text='холода', id='6_8', head_id='6_4', rel='acl')
# DocToken(start=309, stop=310, text=',', id='6_9', head_id='6_8', rel='punct')
# DocToken(start=311, stop=314, text='ему', id='6_10', head_id='6_17', rel='iobj')
# DocToken(start=315, stop=316, text='к', id='6_11', head_id='6_13', rel='case')
# DocToken(start=317, stop=321, text='тому', id='6_12', head_id='6_13', rel='det')
# DocToken(start=322, stop=329, text='времени', id='6_13', head_id='6_17', rel='obl')
# DocToken(start=330, stop=333, text='уже', id='6_14', head_id='6_15', rel='advmod')
# DocToken(start=334, stop=345, text='семнадцатый', id='6_15', head_id='6_16', rel='amod')
# DocToken(start=346, stop=349, text='год', id='6_16', head_id='6_17', rel='obl')
# DocToken(start=350, stop=353, text='шел', id='6_17', head_id='6_0', rel='root')
# DocToken(start=353, stop=354, text=',', id='6_18', head_id='6_20', rel='punct')
# DocToken(start=355, stop=356, text='а', id='6_19', head_id='6_20', rel='cc')
# DocToken(start=357, stop=362, text='Ирина', id='6_20', head_id='6_17', rel='conj')
# DocToken(start=363, stop=366, text='моя', id='6_21', head_id='6_20', rel='det')
# DocToken(start=366, stop=367, text='…', id='6_22', head_id='6_17', rel='punct')
# DocToken(start=368, stop=373, text='Такой', id='7_1', head_id='7_0', rel='root')
# DocToken(start=374, stop=375, text='я', id='7_2', head_id='7_14', rel='nsubj')
# DocToken(start=376, stop=378, text='ее', id='7_3', head_id='7_14', rel='obj')
# DocToken(start=379, stop=381, text='за', id='7_4', head_id='7_7', rel='case')
# DocToken(start=382, stop=385, text='все', id='7_5', head_id='7_6', rel='det')
# DocToken(start=386, stop=396, text='семнадцать', id='7_6', head_id='7_7', rel='nummod:gov')
# DocToken(start=397, stop=400, text='лет', id='7_7', head_id='7_14', rel='obl')
# DocToken(start=401, stop=406, text='нашей', id='7_8', head_id='7_10', rel='det')
# DocToken(start=407, stop=417, text='совместной', id='7_9', head_id='7_10', rel='amod')
# DocToken(start=418, stop=423, text='жизни', id='7_10', head_id='7_7', rel='nmod')
# DocToken(start=424, stop=426, text='ни', id='7_11', head_id='7_7', rel='advmod')
# DocToken(start=427, stop=431, text='разу', id='7_12', head_id='7_11', rel='fixed')
# DocToken(start=432, stop=434, text='не', id='7_13', head_id='7_14', rel='advmod')
# DocToken(start=435, stop=440, text='видал', id='7_14', head_id='7_0', rel='root')
# DocToken(start=440, stop=441, text='.', id='7_15', head_id='7_14', rel='punct')
# DocToken(start=442, stop=447, text='Ночью', id='8_1', head_id='8_14', rel='obl')
# DocToken(start=448, stop=449, text='у', id='8_2', head_id='8_3', rel='case')
# DocToken(start=450, stop=454, text='меня', id='8_3', head_id='8_14', rel='obl')
# DocToken(start=455, stop=457, text='на', id='8_4', head_id='8_5', rel='case')
# DocToken(start=458, stop=463, text='плече', id='8_5', head_id='8_3', rel='nmod')
# DocToken(start=464, stop=465, text='и', id='8_6', head_id='8_8', rel='cc')
# DocToken(start=466, stop=468, text='на', id='8_7', head_id='8_8', rel='case')
# DocToken(start=469, stop=474, text='груди', id='8_8', head_id='8_5', rel='conj')
# DocToken(start=475, stop=481, text='рубаха', id='8_9', head_id='8_8', rel='nmod')
# DocToken(start=482, stop=484, text='от', id='8_10', head_id='8_12', rel='case')
# DocToken(start=485, stop=487, text='ее', id='8_11', head_id='8_12', rel='det')
# DocToken(start=488, stop=492, text='слез', id='8_12', head_id='8_9', rel='nmod')
# DocToken(start=493, stop=495, text='не', id='8_13', head_id='8_14', rel='advmod')
# DocToken(start=496, stop=505, text='просыхала', id='8_14', head_id='8_0', rel='root')
# DocToken(start=505, stop=506, text=',', id='8_15', head_id='8_9', rel='punct')
# DocToken(start=507, stop=508, text='и', id='8_16', head_id='8_9', rel='cc')
# DocToken(start=509, stop=514, text='утром', id='8_17', head_id='8_9', rel='obl')
# DocToken(start=515, stop=520, text='такая', id='8_18', head_id='8_20', rel='det')
# DocToken(start=521, stop=523, text='же', id='8_19', head_id='8_18', rel='advmod')
# DocToken(start=524, stop=531, text='история', id='8_20', head_id='8_9', rel='obj')
# DocToken(start=531, stop=532, text='…', id='8_21', head_id='8_14', rel='punct')
# DocToken(start=533, stop=539, text='Пришли', id='9_1', head_id='9_0', rel='root')
# DocToken(start=540, stop=542, text='на', id='9_2', head_id='9_3', rel='case')
# DocToken(start=543, stop=549, text='вокзал', id='9_3', head_id='9_1', rel='obl')
# DocToken(start=549, stop=550, text=',', id='9_4', head_id='9_26', rel='punct')
# DocToken(start=551, stop=552, text='а', id='9_5', head_id='9_26', rel='cc')
# DocToken(start=553, stop=554, text='я', id='9_6', head_id='9_33', rel='nsubj')
# DocToken(start=555, stop=557, text='на', id='9_7', head_id='9_8', rel='case')
# DocToken(start=558, stop=561, text='нее', id='9_8', head_id='9_26', rel='nmod')
# DocToken(start=562, stop=564, text='от', id='9_9', head_id='9_10', rel='case')
# DocToken(start=565, stop=572, text='жалости', id='9_10', head_id='9_8', rel='nmod')
# DocToken(start=573, stop=580, text='глядеть', id='9_11', head_id='9_13', rel='xcomp')
# DocToken(start=581, stop=583, text='не', id='9_12', head_id='9_13', rel='advmod')
# DocToken(start=584, stop=588, text='могу', id='9_13', head_id='9_0', rel='root')
# DocToken(start=588, stop=589, text=':', id='9_14', head_id='9_23', rel='punct')
# DocToken(start=590, stop=594, text='губы', id='9_15', head_id='9_23', rel='nsubj')
# DocToken(start=595, stop=597, text='от', id='9_16', head_id='9_17', rel='case')
# DocToken(start=598, stop=602, text='слез', id='9_17', head_id='9_34', rel='nmod')
# DocToken(start=603, stop=611, text='распухли', id='9_18', head_id='9_17', rel='nmod')
# DocToken(start=611, stop=612, text=',', id='9_19', head_id='9_33', rel='punct')
# DocToken(start=613, stop=619, text='волосы', id='9_20', head_id='9_15', rel='conj')
# DocToken(start=620, stop=626, text='из-под', id='9_21', head_id='9_23', rel='case')
# DocToken(start=627, stop=633, text='платка', id='9_22', head_id='9_23', rel='obl')
# DocToken(start=634, stop=642, text='выбились', id='9_23', head_id='9_13', rel='parataxis')
# DocToken(start=642, stop=643, text=',', id='9_24', head_id='9_26', rel='punct')
# DocToken(start=644, stop=645, text='и', id='9_25', head_id='9_26', rel='cc')
# DocToken(start=646, stop=651, text='глаза', id='9_26', head_id='9_26', rel='conj')
# DocToken(start=652, stop=658, text='мутные', id='9_27', head_id='9_18', rel='conj')
# DocToken(start=658, stop=659, text=',', id='9_28', head_id='9_29', rel='punct')
# DocToken(start=660, stop=672, text='несмысленные', id='9_29', head_id='9_18', rel='conj')
# DocToken(start=672, stop=673, text=',', id='9_30', head_id='9_33', rel='punct')
# DocToken(start=674, stop=677, text='как', id='9_31', head_id='9_33', rel='mark')
# DocToken(start=678, stop=679, text='у', id='9_32', head_id='9_34', rel='case')
# DocToken(start=680, stop=689, text='тронутого', id='9_33', head_id='9_18', rel='acl')
# DocToken(start=690, stop=694, text='умом', id='9_34', head_id='9_33', rel='obl')
# DocToken(start=695, stop=703, text='человека', id='9_35', head_id='9_34', rel='nmod')
# DocToken(start=703, stop=704, text='.', id='9_36', head_id='9_1', rel='punct')
# DocToken(start=705, stop=714, text='Командиры', id='10_1', head_id='10_2', rel='nsubj')
# DocToken(start=715, stop=724, text='объявляют', id='10_2', head_id='10_0', rel='root')
# DocToken(start=725, stop=732, text='посадку', id='10_3', head_id='10_2', rel='obj')
# DocToken(start=732, stop=733, text=',', id='10_4', head_id='10_7', rel='punct')
# DocToken(start=734, stop=735, text='а', id='10_5', head_id='10_7', rel='cc')
# DocToken(start=736, stop=739, text='она', id='10_6', head_id='10_7', rel='nsubj')
# DocToken(start=740, stop=745, text='упала', id='10_7', head_id='10_2', rel='conj')
# DocToken(start=746, stop=749, text='мне', id='10_8', head_id='10_7', rel='iobj')
# DocToken(start=750, stop=752, text='на', id='10_9', head_id='10_10', rel='case')
# DocToken(start=753, stop=758, text='грудь', id='10_10', head_id='10_7', rel='obl')
# DocToken(start=758, stop=759, text=',', id='10_11', head_id='10_7', rel='punct')
# DocToken(start=760, stop=764, text='руки', id='10_12', head_id='10_16', rel='conj')
# DocToken(start=765, stop=767, text='на', id='10_13', head_id='10_15', rel='case')
# DocToken(start=768, stop=772, text='моей', id='10_14', head_id='10_15', rel='det')
# DocToken(start=773, stop=776, text='шее', id='10_15', head_id='10_7', rel='obl')
# DocToken(start=777, stop=784, text='сцепила', id='10_16', head_id='10_2', rel='conj')
# DocToken(start=785, stop=786, text='и', id='10_17', head_id='10_7', rel='cc')
# DocToken(start=787, stop=790, text='вся', id='10_18', head_id='10_19', rel='det')
# DocToken(start=791, stop=797, text='дрожит', id='10_19', head_id='10_2', rel='conj')
# DocToken(start=797, stop=798, text=',', id='10_20', head_id='10_7', rel='punct')
# DocToken(start=799, stop=804, text='будто', id='10_21', head_id='10_22', rel='mark')
# DocToken(start=805, stop=817, text='подрубленное', id='10_22', head_id='10_19', rel='advcl')
# DocToken(start=818, stop=824, text='дерево', id='10_23', head_id='10_7', rel='obj')
# DocToken(start=824, stop=825, text='…', id='10_24', head_id='10_2', rel='punct')
# DocToken(start=826, stop=827, text='И', id='11_1', head_id='11_4', rel='cc')
# DocToken(start=828, stop=835, text='детишки', id='11_2', head_id='11_0', rel='root')
# DocToken(start=836, stop=838, text='ее', id='11_3', head_id='11_4', rel='obj')
# DocToken(start=839, stop=850, text='уговаривают', id='11_4', head_id='11_0', rel='root')
# DocToken(start=850, stop=851, text=',', id='11_5', head_id='11_12', rel='punct')
# DocToken(start=852, stop=853, text='и', id='11_6', head_id='11_12', rel='cc')
# DocToken(start=854, stop=855, text='я', id='11_7', head_id='11_12', rel='nsubj')
# DocToken(start=855, stop=856, text=',', id='11_8', head_id='11_7', rel='punct')
# DocToken(start=857, stop=858, text='—', id='11_9', head_id='11_12', rel='punct')
# DocToken(start=859, stop=865, text='ничего', id='11_10', head_id='11_12', rel='obj')
# DocToken(start=866, stop=868, text='не', id='11_11', head_id='11_12', rel='advmod')
# DocToken(start=869, stop=877, text='помогает', id='11_12', head_id='11_4', rel='conj')
# DocToken(start=877, stop=878, text='!', id='11_13', head_id='11_4', rel='punct')
# DocToken(start=879, stop=885, text='Другие', id='12_1', head_id='12_2', rel='amod')
# DocToken(start=886, stop=893, text='женщины', id='12_2', head_id='12_30', rel='nsubj')
# DocToken(start=894, stop=895, text='с', id='12_3', head_id='12_4', rel='case')
# DocToken(start=896, stop=903, text='мужьями', id='12_4', head_id='12_2', rel='nmod')
# DocToken(start=903, stop=904, text=',', id='12_5', head_id='12_17', rel='punct')
# DocToken(start=905, stop=906, text='с', id='12_6', head_id='12_7', rel='case')
# DocToken(start=907, stop=916, text='сыновьями', id='12_7', head_id='12_8', rel='obl')
# DocToken(start=917, stop=930, text='разговаривают', id='12_8', head_id='12_0', rel='root')
# DocToken(start=930, stop=931, text=',', id='12_9', head_id='12_30', rel='punct')
# DocToken(start=932, stop=933, text='а', id='12_10', head_id='12_30', rel='cc')
# DocToken(start=934, stop=937, text='моя', id='12_11', head_id='12_12', rel='det')
# DocToken(start=938, stop=947, text='прижалась', id='12_12', head_id='12_8', rel='nsubj')
# DocToken(start=948, stop=950, text='ко', id='12_13', head_id='12_14', rel='case')
# DocToken(start=951, stop=954, text='мне', id='12_14', head_id='12_12', rel='obl')
# DocToken(start=954, stop=955, text=',', id='12_15', head_id='12_17', rel='punct')
# DocToken(start=956, stop=959, text='как', id='12_16', head_id='12_17', rel='case')
# DocToken(start=960, stop=964, text='лист', id='12_17', head_id='12_12', rel='obl')
# DocToken(start=965, stop=966, text='к', id='12_18', head_id='12_19', rel='case')
# DocToken(start=967, stop=972, text='ветке', id='12_19', head_id='12_12', rel='obl')
# DocToken(start=972, stop=973, text=',', id='12_20', head_id='12_30', rel='punct')
# DocToken(start=974, stop=975, text='и', id='12_21', head_id='12_30', rel='cc')
# DocToken(start=976, stop=982, text='только', id='12_22', head_id='12_24', rel='advmod')
# DocToken(start=983, stop=986, text='вся', id='12_23', head_id='12_24', rel='nsubj')
# DocToken(start=987, stop=993, text='дрожит', id='12_24', head_id='12_8', rel='conj')
# DocToken(start=993, stop=994, text=',', id='12_25', head_id='12_30', rel='punct')
# DocToken(start=995, stop=996, text='а', id='12_26', head_id='12_30', rel='cc')
# DocToken(start=997, stop=1002, text='слова', id='12_27', head_id='12_30', rel='nsubj')
# DocToken(start=1003, stop=1012, text='вымолвить', id='12_28', head_id='12_27', rel='nmod')
# DocToken(start=1013, stop=1015, text='не', id='12_29', head_id='12_30', rel='advmod')
# DocToken(start=1016, stop=1021, text='может', id='12_30', head_id='12_8', rel='conj')
# DocToken(start=1021, stop=1022, text='.', id='12_31', head_id='12_8', rel='punct')
# DocToken(start=1023, stop=1024, text='Я', id='13_1', head_id='13_3', rel='nsubj')
# DocToken(start=1025, stop=1026, text='и', id='13_2', head_id='13_3', rel='advmod')
# DocToken(start=1027, stop=1033, text='говорю', id='13_3', head_id='13_0', rel='root')
# DocToken(start=1034, stop=1036, text='ей', id='13_4', head_id='13_3', rel='iobj')
# DocToken(start=1036, stop=1037, text=':', id='13_5', head_id='13_7', rel='punct')
# DocToken(start=1038, stop=1039, text='«', id='13_6', head_id='13_7', rel='punct')
# DocToken(start=1039, stop=1045, text='Возьми', id='13_7', head_id='13_3', rel='parataxis')
# DocToken(start=1046, stop=1048, text='же', id='13_8', head_id='13_7', rel='advmod')
# DocToken(start=1049, stop=1053, text='себя', id='13_9', head_id='13_7', rel='obj')
# DocToken(start=1054, stop=1055, text='в', id='13_10', head_id='13_11', rel='case')
# DocToken(start=1056, stop=1060, text='руки', id='13_11', head_id='13_7', rel='obl')
# DocToken(start=1060, stop=1061, text=',', id='13_12', head_id='13_15', rel='punct')
# DocToken(start=1062, stop=1067, text='милая', id='13_13', head_id='13_15', rel='amod')
# DocToken(start=1068, stop=1071, text='моя', id='13_14', head_id='13_15', rel='det')
# DocToken(start=1072, stop=1078, text='Иринка', id='13_15', head_id='13_7', rel='conj')
# DocToken(start=1078, stop=1079, text='!', id='13_16', head_id='13_3', rel='punct')
# DocToken(start=1080, stop=1085, text='Скажи', id='14_1', head_id='14_0', rel='root')
# DocToken(start=1086, stop=1089, text='мне', id='14_2', head_id='14_1', rel='iobj')
# DocToken(start=1090, stop=1094, text='хоть', id='14_3', head_id='14_4', rel='advmod')
# DocToken(start=1095, stop=1100, text='слово', id='14_4', head_id='14_1', rel='obj')
# DocToken(start=1101, stop=1103, text='на', id='14_5', head_id='14_6', rel='case')
# DocToken(start=1104, stop=1112, text='прощанье', id='14_6', head_id='14_4', rel='nmod')
# DocToken(start=1112, stop=1113, text='»', id='14_7', head_id='14_4', rel='punct')
# DocToken(start=1113, stop=1114, text='.', id='14_8', head_id='14_1', rel='punct')
# DocToken(start=1115, stop=1118, text='Она', id='15_1', head_id='15_3', rel='nsubj')
# DocToken(start=1119, stop=1120, text='и', id='15_2', head_id='15_3', rel='advmod')
# DocToken(start=1121, stop=1128, text='говорит', id='15_3', head_id='15_0', rel='root')
# DocToken(start=1128, stop=1129, text=',', id='15_4', head_id='15_8', rel='punct')
# DocToken(start=1130, stop=1131, text='и', id='15_5', head_id='15_8', rel='cc')
# DocToken(start=1132, stop=1134, text='за', id='15_6', head_id='15_8', rel='case')
# DocToken(start=1135, stop=1141, text='каждым', id='15_7', head_id='15_8', rel='det')
# DocToken(start=1142, stop=1148, text='словом', id='15_8', head_id='15_9', rel='obl')
# DocToken(start=1149, stop=1160, text='всхлипывает', id='15_9', head_id='15_9', rel='parataxis')
# DocToken(start=1160, stop=1161, text=':', id='15_10', head_id='15_12', rel='punct')
# DocToken(start=1162, stop=1163, text='«', id='15_11', head_id='15_12', rel='punct')
# DocToken(start=1163, stop=1173, text='Родненький', id='15_12', head_id='15_9', rel='parataxis')
# DocToken(start=1174, stop=1177, text='мой', id='15_13', head_id='15_12', rel='obj')
# DocToken(start=1177, stop=1178, text='…', id='15_14', head_id='15_3', rel='punct')
# DocToken(start=1179, stop=1186, text='Андрюша', id='16_1', head_id='16_0', rel='root')
# DocToken(start=1186, stop=1187, text='…', id='16_2', head_id='16_1', rel='punct')
# DocToken(start=1188, stop=1190, text='не', id='16_3', head_id='16_4', rel='advmod')
# DocToken(start=1191, stop=1199, text='увидимся', id='16_4', head_id='16_0', rel='root')
# DocToken(start=1200, stop=1202, text='мы', id='16_5', head_id='16_4', rel='nsubj')
# DocToken(start=1203, stop=1204, text='с', id='16_6', head_id='16_7', rel='case')
# DocToken(start=1205, stop=1210, text='тобой', id='16_7', head_id='16_4', rel='obl')
# DocToken(start=1210, stop=1211, text='…', id='16_8', head_id='16_9', rel='punct')
# DocToken(start=1212, stop=1218, text='больше', id='16_9', head_id='16_0', rel='root')
# DocToken(start=1218, stop=1219, text='…', id='16_10', head_id='16_9', rel='punct')
# DocToken(start=1220, stop=1222, text='на', id='16_11', head_id='16_12', rel='case')
# DocToken(start=1223, stop=1227, text='этом', id='16_12', head_id='16_9', rel='obl')
# DocToken(start=1227, stop=1228, text='…', id='16_13', head_id='16_14', rel='punct')
# DocToken(start=1229, stop=1234, text='свете', id='16_14', head_id='16_9', rel='obl')
# DocToken(start=1234, stop=1235, text='»', id='16_15', head_id='16_14', rel='punct')
# DocToken(start=1235, stop=1236, text='…', id='16_16', head_id='16_1', rel='punct')
# DocToken(start=1238, stop=1241, text='Тут', id='17_1', head_id='17_11', rel='advmod')
# DocToken(start=1242, stop=1243, text='у', id='17_2', head_id='17_5', rel='case')
# DocToken(start=1244, stop=1250, text='самого', id='17_3', head_id='17_8', rel='amod')
# DocToken(start=1251, stop=1253, text='от', id='17_4', head_id='17_5', rel='case')
# DocToken(start=1254, stop=1261, text='жалости', id='17_5', head_id='17_11', rel='obl')
# DocToken(start=1262, stop=1263, text='к', id='17_6', head_id='17_7', rel='case')
# DocToken(start=1264, stop=1267, text='ней', id='17_7', head_id='17_5', rel='nmod')
# DocToken(start=1268, stop=1274, text='сердце', id='17_8', head_id='17_5', rel='nsubj')
# DocToken(start=1275, stop=1277, text='на', id='17_9', head_id='17_10', rel='case')
# DocToken(start=1278, stop=1283, text='части', id='17_10', head_id='17_11', rel='obl')
# DocToken(start=1284, stop=1295, text='разрывается', id='17_11', head_id='17_0', rel='root')
# DocToken(start=1295, stop=1296, text=',', id='17_12', head_id='17_15', rel='punct')
# DocToken(start=1297, stop=1298, text='а', id='17_13', head_id='17_18', rel='cc')
# DocToken(start=1299, stop=1302, text='тут', id='17_14', head_id='17_18', rel='advmod')
# DocToken(start=1303, stop=1306, text='она', id='17_15', head_id='17_11', rel='nsubj')
# DocToken(start=1307, stop=1308, text='с', id='17_16', head_id='17_18', rel='case')
# DocToken(start=1309, stop=1315, text='такими', id='17_17', head_id='17_18', rel='det')
# DocToken(start=1316, stop=1323, text='словами', id='17_18', head_id='17_15', rel='orphan')
# DocToken(start=1323, stop=1324, text='.', id='17_19', head_id='17_11', rel='punct')
# DocToken(start=1325, stop=1331, text='Должна', id='18_1', head_id='18_0', rel='root')
# DocToken(start=1332, stop=1334, text='бы', id='18_2', head_id='18_1', rel='aux')
# DocToken(start=1335, stop=1343, text='понимать', id='18_3', head_id='18_1', rel='xcomp')
# DocToken(start=1343, stop=1344, text=',', id='18_4', head_id='18_8', rel='punct')
# DocToken(start=1345, stop=1348, text='что', id='18_5', head_id='18_8', rel='mark')
# DocToken(start=1349, stop=1352, text='мне', id='18_6', head_id='18_8', rel='iobj')
# DocToken(start=1353, stop=1357, text='тоже', id='18_7', head_id='18_8', rel='advmod')
# DocToken(start=1358, stop=1365, text='нелегко', id='18_8', head_id='18_3', rel='ccomp')
# DocToken(start=1366, stop=1367, text='с', id='18_9', head_id='18_10', rel='case')
# DocToken(start=1368, stop=1372, text='ними', id='18_10', head_id='18_11', rel='obl')
# DocToken(start=1373, stop=1385, text='расставаться', id='18_11', head_id='18_8', rel='csubj')
# DocToken(start=1385, stop=1386, text=',', id='18_12', head_id='18_18', rel='punct')
# DocToken(start=1387, stop=1389, text='не', id='18_13', head_id='18_15', rel='advmod')
# DocToken(start=1390, stop=1391, text='к', id='18_14', head_id='18_15', rel='case')
# DocToken(start=1392, stop=1396, text='теще', id='18_15', head_id='18_11', rel='obl')
# DocToken(start=1397, stop=1399, text='на', id='18_16', head_id='18_17', rel='case')
# DocToken(start=1400, stop=1405, text='блины', id='18_17', head_id='18_18', rel='obl')
# DocToken(start=1406, stop=1414, text='собрался', id='18_18', head_id='18_3', rel='ccomp')
# DocToken(start=1414, stop=1415, text='.', id='18_19', head_id='18_1', rel='punct')
# DocToken(start=1416, stop=1419, text='Зло', id='19_1', head_id='19_4', rel='obj')
# DocToken(start=1420, stop=1424, text='меня', id='19_2', head_id='19_4', rel='obj')
# DocToken(start=1425, stop=1428, text='тут', id='19_3', head_id='19_4', rel='advmod')
# DocToken(start=1429, stop=1434, text='взяло', id='19_4', head_id='19_0', rel='root')
# DocToken(start=1434, stop=1435, text='!', id='19_5', head_id='19_4', rel='punct')
# DocToken(start=1436, stop=1441, text='Силой', id='20_1', head_id='20_3', rel='obl')
# DocToken(start=1442, stop=1443, text='я', id='20_2', head_id='20_3', rel='nsubj')
# DocToken(start=1444, stop=1450, text='разнял', id='20_3', head_id='20_0', rel='root')
# DocToken(start=1451, stop=1453, text='ее', id='20_4', head_id='20_5', rel='det')
# DocToken(start=1454, stop=1458, text='руки', id='20_5', head_id='20_3', rel='obj')
# DocToken(start=1459, stop=1460, text='и', id='20_6', head_id='20_7', rel='cc')
# DocToken(start=1461, stop=1469, text='легонько', id='20_7', head_id='20_3', rel='conj')
# DocToken(start=1470, stop=1477, text='толкнул', id='20_8', head_id='20_3', rel='conj')
# DocToken(start=1478, stop=1479, text='в', id='20_9', head_id='20_10', rel='case')
# DocToken(start=1480, stop=1485, text='плечи', id='20_10', head_id='20_8', rel='obl')
# DocToken(start=1485, stop=1486, text='.', id='20_11', head_id='20_3', rel='punct')
# DocToken(start=1487, stop=1494, text='Толкнул', id='21_1', head_id='21_0', rel='root')
# DocToken(start=1495, stop=1500, text='вроде', id='21_2', head_id='21_3', rel='advmod')
# DocToken(start=1501, stop=1509, text='легонько', id='21_3', head_id='21_1', rel='xcomp')
# DocToken(start=1509, stop=1510, text=',', id='21_4', head_id='21_32', rel='punct')
# DocToken(start=1511, stop=1512, text='а', id='21_5', head_id='21_32', rel='cc')
# DocToken(start=1513, stop=1520, text='сила-то', id='21_6', head_id='21_40', rel='nsubj')
# DocToken(start=1521, stop=1522, text='у', id='21_7', head_id='21_8', rel='case')
# DocToken(start=1523, stop=1527, text='меня', id='21_8', head_id='21_23', rel='obl')
# DocToken(start=1528, stop=1532, text='была', id='21_9', head_id='21_10', rel='conj')
# DocToken(start=1533, stop=1540, text='дурачья', id='21_10', head_id='21_1', rel='conj')
# DocToken(start=1540, stop=1541, text=';', id='21_11', head_id='21_13', rel='punct')
# DocToken(start=1542, stop=1545, text='она', id='21_12', head_id='21_13', rel='nsubj')
# DocToken(start=1546, stop=1556, text='попятилась', id='21_13', head_id='21_1', rel='conj')
# DocToken(start=1556, stop=1557, text=',', id='21_14', head_id='21_15', rel='punct')
# DocToken(start=1558, stop=1562, text='шага', id='21_15', head_id='21_23', rel='advcl')
# DocToken(start=1563, stop=1566, text='три', id='21_16', head_id='21_17', rel='nummod:gov')
# DocToken(start=1567, stop=1575, text='ступнула', id='21_17', head_id='21_32', rel='obj')
# DocToken(start=1576, stop=1581, text='назад', id='21_18', head_id='21_17', rel='advmod')
# DocToken(start=1582, stop=1583, text='и', id='21_19', head_id='21_40', rel='cc')
# DocToken(start=1584, stop=1589, text='опять', id='21_20', head_id='21_40', rel='advmod')
# DocToken(start=1590, stop=1592, text='ко', id='21_21', head_id='21_22', rel='case')
# DocToken(start=1593, stop=1596, text='мне', id='21_22', head_id='21_23', rel='obl')
# DocToken(start=1597, stop=1601, text='идет', id='21_23', head_id='21_1', rel='conj')
# DocToken(start=1602, stop=1609, text='мелкими', id='21_24', head_id='21_25', rel='amod')
# DocToken(start=1610, stop=1617, text='шажками', id='21_25', head_id='21_23', rel='obl')
# DocToken(start=1617, stop=1618, text=',', id='21_26', head_id='21_28', rel='punct')
# DocToken(start=1619, stop=1623, text='руки', id='21_27', head_id='21_28', rel='obj')
# DocToken(start=1624, stop=1635, text='протягивает', id='21_28', head_id='21_1', rel='conj')
# DocToken(start=1635, stop=1636, text=',', id='21_29', head_id='21_32', rel='punct')
# DocToken(start=1637, stop=1638, text='а', id='21_30', head_id='21_32', rel='cc')
# DocToken(start=1639, stop=1640, text='я', id='21_31', head_id='21_32', rel='nsubj')
# DocToken(start=1641, stop=1646, text='кричу', id='21_32', head_id='21_1', rel='conj')
# DocToken(start=1647, stop=1649, text='ей', id='21_33', head_id='21_32', rel='iobj')
# DocToken(start=1649, stop=1650, text=':', id='21_34', head_id='21_23', rel='punct')
# DocToken(start=1651, stop=1652, text='«', id='21_35', head_id='21_40', rel='punct')
# DocToken(start=1652, stop=1654, text='Да', id='21_36', head_id='21_40', rel='cc')
# DocToken(start=1655, stop=1660, text='разве', id='21_37', head_id='21_23', rel='advmod')
# DocToken(start=1661, stop=1663, text='же', id='21_38', head_id='21_37', rel='advmod')
# DocToken(start=1664, stop=1667, text='так', id='21_39', head_id='21_40', rel='advmod')
# DocToken(start=1668, stop=1677, text='прощаются', id='21_40', head_id='21_32', rel='parataxis')
# DocToken(start=1677, stop=1678, text='?', id='21_41', head_id='21_1', rel='punct')
# DocToken(start=1679, stop=1682, text='Что', id='22_1', head_id='22_6', rel='obj')
# DocToken(start=1683, stop=1685, text='ты', id='22_2', head_id='22_7', rel='nsubj')
# DocToken(start=1686, stop=1690, text='меня', id='22_3', head_id='22_7', rel='obj')
# DocToken(start=1691, stop=1697, text='раньше', id='22_4', head_id='22_7', rel='advmod')
# DocToken(start=1698, stop=1705, text='времени', id='22_5', head_id='22_6', rel='obl')
# DocToken(start=1706, stop=1712, text='заживо', id='22_6', head_id='22_7', rel='advmod')
# DocToken(start=1713, stop=1721, text='хоронишь', id='22_7', head_id='22_6', rel='obl')
# DocToken(start=1721, stop=1723, text='?!', id='22_8', head_id='22_7', rel='punct')
# DocToken(start=1723, stop=1724, text='»', id='22_9', head_id='22_7', rel='punct')
# DocToken(start=1725, stop=1727, text='Ну', id='23_1', head_id='23_4', rel='parataxis')
# DocToken(start=1727, stop=1728, text=',', id='23_2', head_id='23_1', rel='punct')
# DocToken(start=1729, stop=1734, text='опять', id='23_3', head_id='23_4', rel='advmod')
# DocToken(start=1735, stop=1740, text='обнял', id='23_4', head_id='23_0', rel='root')
# DocToken(start=1741, stop=1743, text='ее', id='23_5', head_id='23_4', rel='obj')
# DocToken(start=1743, stop=1744, text=',', id='23_6', head_id='23_7', rel='punct')
# DocToken(start=1745, stop=1749, text='вижу', id='23_7', head_id='23_0', rel='root')
# DocToken(start=1749, stop=1750, text=',', id='23_8', head_id='23_13', rel='punct')
# DocToken(start=1751, stop=1754, text='что', id='23_9', head_id='23_13', rel='mark')
# DocToken(start=1755, stop=1758, text='она', id='23_10', head_id='23_13', rel='nsubj')
# DocToken(start=1759, stop=1761, text='не', id='23_11', head_id='23_13', rel='advmod')
# DocToken(start=1762, stop=1763, text='в', id='23_12', head_id='23_13', rel='case')
# DocToken(start=1764, stop=1768, text='себе', id='23_13', head_id='23_7', rel='ccomp')
# DocToken(start=1768, stop=1769, text='…', id='23_14', head_id='23_4', rel='punct')

# %%
doc.sents[0].syntax.print()
# Out:
#         ┌► А     cc
# ┌───┌─┌─└─ тут
# │   │ └──► вот   advmod
# │ ┌─└────► она   nsubj
# │ │     ┌► ,     punct
# │ └────►└─ война conj
# └────────► .     punct
